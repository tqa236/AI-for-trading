# %% [markdown]
# # Project 2: Breakout Strategy
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment. After implementing the function, run the cell to test it against the unit tests we've provided. For each problem, we provide one or more unit tests from our `project_tests` package. These unit tests won't tell you if your answer is correct, but will warn you of any major errors. Your code will be checked for the correct solution when you submit it to Udacity.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# The other packages that we're importing are `helper`, `project_helper`, and `project_tests`. These are custom packages built to help you solve the problems.  The `helper` and `project_helper` module contains utility functions and graph functions. The `project_tests` contains the unit tests for all the problems.
#
# ### Install Packages

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: colour>=0.1.5 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (0.1.5)
# Requirement already satisfied: cvxpy>=1.0.3 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.0.31)
# Requirement already satisfied: cycler>=0.10.0 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (1.18.1)
# Requirement already satisfied: pandas>=0.21.1 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (1.0.3)
# Requirement already satisfied: plotly>=2.2.3 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 6)) (4.7.1)
# Requirement already satisfied: pyparsing>=2.2.0 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 7)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 9)) (2019.3)
# Requirement already satisfied: requests>=2.18.4 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 10)) (2.22.0)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 11)) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 12)) (0.23.1)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 13)) (1.14.0)
# Requirement already satisfied: tqdm>=4.19.5 in /opt/conda/lib/python3.7/site-packages (from -r requirements.txt (line 14)) (4.42.1)
# Collecting zipline>=1.2.0
#   Using cached zipline-1.3.0.tar.gz (2.5 MB)
# Requirement already satisfied: ecos>=2 in /opt/conda/lib/python3.7/site-packages (from cvxpy>=1.0.3->-r requirements.txt (line 2)) (2.0.7.post1)
# Requirement already satisfied: osqp>=0.4.1 in /opt/conda/lib/python3.7/site-packages (from cvxpy>=1.0.3->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: scs>=1.1.3 in /opt/conda/lib/python3.7/site-packages (from cvxpy>=1.0.3->-r requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.7/site-packages (from cvxpy>=1.0.3->-r requirements.txt (line 2)) (0.70.9)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from plotly>=2.2.3->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.18.4->-r requirements.txt (line 10)) (2020.4.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.18.4->-r requirements.txt (line 10)) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.18.4->-r requirements.txt (line 10)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.18.4->-r requirements.txt (line 10)) (1.25.8)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.19.1->-r requirements.txt (line 12)) (0.15.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.19.1->-r requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: pip>=7.1.0 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (20.0.2)
# Requirement already satisfied: setuptools>18.0 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (45.2.0.post20200210)
# Requirement already satisfied: Logbook>=0.12.5 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (1.5.3)
# Requirement already satisfied: requests-file>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (1.5.1)
# Requirement already satisfied: pandas-datareader>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (0.8.1)
# Requirement already satisfied: patsy>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: statsmodels>=0.6.1 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (0.11.1)
# Requirement already satisfied: Cython>=0.25.2 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (0.29.18)
# Collecting cyordereddict>=0.2.2
#   Using cached cyordereddict-1.0.0.tar.gz (138 kB)
# Processing /root/.cache/pip/wheels/87/85/9c/a325c89ff0498660ef8a335fb4b3912939c273ea4f094af29f/Bottleneck-1.3.2-cp37-cp37m-linux_x86_64.whl
# Collecting contextlib2>=0.4.0
#   Using cached contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: decorator>=4.0.0 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (4.4.2)
# Collecting networkx<2.0,>=1.9.1
#   Using cached networkx-1.11-py2.py3-none-any.whl (1.3 MB)
# Collecting numexpr>=2.6.1
#   Using cached numexpr-2.7.1-cp37-cp37m-manylinux1_x86_64.whl (162 kB)
# Collecting bcolz<1,>=0.12.1
#   Using cached bcolz-0.12.1.tar.gz (622 kB)
# Collecting click>=4.0.0
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Processing /root/.cache/pip/wheels/e2/83/7c/248063997a4f9ff6bf145822e620e8c37117a6b4c765584077/toolz-0.10.0-py3-none-any.whl
# Collecting multipledispatch>=0.4.8
#   Using cached multipledispatch-0.6.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from zipline>=1.2.0->-r requirements.txt (line 15)) (1.1.1)
# Collecting Mako>=1.0.1
#   Using cached Mako-1.1.2-py2.py3-none-any.whl (75 kB)
# Collecting sqlalchemy>=1.0.8
#   Using cached SQLAlchemy-1.3.17-cp37-cp37m-manylinux2010_x86_64.whl (1.2 MB)
# Processing /root/.cache/pip/wheels/4e/b5/00/f93fe1c90b3d501774e91e2e99987f49d16019e40e4bd3afc3/alembic-1.4.2-py2.py3-none-any.whl
# Collecting sortedcontainers>=1.4.4
#   Using cached sortedcontainers-2.1.0-py2.py3-none-any.whl (28 kB)
# Processing /root/.cache/pip/wheels/68/2d/6f/68fdd1342f58dac32f7d2781b00e9fd43b15d51e4c1ff9b4fb/intervaltree-3.0.2-py3-none-any.whl
# Processing /root/.cache/pip/wheels/01/a8/08/242afb3f48be064b2f2ef8e1ad115d43cde698fdd6f212f825/lru_dict-1.1.6-cp37-cp37m-linux_x86_64.whl
# Processing /root/.cache/pip/wheels/14/37/00/4e984eafe752f6df04a3b6c31c7ef42a0e9c5173ca5f2156d2/empyrical-0.5.3-py3-none-any.whl
# Collecting tables>=3.3.0
#   Using cached tables-3.6.1-cp37-cp37m-manylinux1_x86_64.whl (4.3 MB)
# Processing /root/.cache/pip/wheels/ec/0a/76/62b18de5e8bccb2b6983e946ecb6f8814a6664b0be9c473ae1/trading_calendars-1.11.7-py3-none-any.whl
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from osqp>=0.4.1->cvxpy>=1.0.3->-r requirements.txt (line 2)) (0.18.2)
# Requirement already satisfied: dill>=0.3.1 in /opt/conda/lib/python3.7/site-packages (from multiprocess->cvxpy>=1.0.3->-r requirements.txt (line 2)) (0.3.1.1)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.7/site-packages (from pandas-datareader>=0.2.1->zipline>=1.2.0->-r requirements.txt (line 15)) (4.5.1)
# Collecting python-editor>=0.3
#   Using cached python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Building wheels for collected packages: zipline, cyordereddict, bcolz
#   Building wheel for zipline (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-vombu9hl/zipline/setup.py'"'"'; __file__='"'"'/tmp/pip-install-vombu9hl/zipline/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-m5j5tv56
#        cwd: /tmp/pip-install-vombu9hl/zipline/
#   Complete output (307 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.7
#   creating build/lib.linux-x86_64-3.7/zipline
#   copying zipline/api.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/zipline_warnings.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/__init__.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/extensions.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/_version.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/dispatch.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/errors.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/protocol.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/__main__.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/algorithm.py -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/test_algorithms.py -> build/lib.linux-x86_64-3.7/zipline
#   creating build/lib.linux-x86_64-3.7/zipline/gens
#   copying zipline/gens/tradesimulation.py -> build/lib.linux-x86_64-3.7/zipline/gens
#   copying zipline/gens/composites.py -> build/lib.linux-x86_64-3.7/zipline/gens
#   copying zipline/gens/__init__.py -> build/lib.linux-x86_64-3.7/zipline/gens
#   copying zipline/gens/utils.py -> build/lib.linux-x86_64-3.7/zipline/gens
#   creating build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/assets.py -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/roll_finder.py -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/asset_writer.py -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/synthetic.py -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/__init__.py -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/asset_db_migrations.py -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/futures.py -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/asset_db_schema.py -> build/lib.linux-x86_64-3.7/zipline/assets
#   creating build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/downsample_helpers.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/engine.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/__init__.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/sentinels.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/api_utils.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/visualize.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/dtypes.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/graph.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/pipeline.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/expression.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/term.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/mixins.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   copying zipline/pipeline/common.py -> build/lib.linux-x86_64-3.7/zipline/pipeline
#   creating build/lib.linux-x86_64-3.7/zipline/testing
#   copying zipline/testing/predicates.py -> build/lib.linux-x86_64-3.7/zipline/testing
#   copying zipline/testing/__init__.py -> build/lib.linux-x86_64-3.7/zipline/testing
#   copying zipline/testing/core.py -> build/lib.linux-x86_64-3.7/zipline/testing
#   copying zipline/testing/slippage.py -> build/lib.linux-x86_64-3.7/zipline/testing
#   copying zipline/testing/fixtures.py -> build/lib.linux-x86_64-3.7/zipline/testing
#   creating build/lib.linux-x86_64-3.7/zipline/examples
#   copying zipline/examples/dual_moving_average.py -> build/lib.linux-x86_64-3.7/zipline/examples
#   copying zipline/examples/momentum_pipeline.py -> build/lib.linux-x86_64-3.7/zipline/examples
#   copying zipline/examples/buyapple.py -> build/lib.linux-x86_64-3.7/zipline/examples
#   copying zipline/examples/__init__.py -> build/lib.linux-x86_64-3.7/zipline/examples
#   copying zipline/examples/olmar.py -> build/lib.linux-x86_64-3.7/zipline/examples
#   copying zipline/examples/buy_and_hold.py -> build/lib.linux-x86_64-3.7/zipline/examples
#   copying zipline/examples/dual_ema_talib.py -> build/lib.linux-x86_64-3.7/zipline/examples
#   creating build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/position.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/order.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/asset_restrictions.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/ledger.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/__init__.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/cancel_policy.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/transaction.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/commission.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/shared.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/controls.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/constants.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/trading.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/execution.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/finance/slippage.py -> build/lib.linux-x86_64-3.7/zipline/finance
#   creating build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/benchmarks.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/history_loader.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/treasuries_can.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/bar_reader.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/resample.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/continuous_future_reader.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/__init__.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/session_bars.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/treasuries.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/dispatch_bar_reader.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/data_portal.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/us_equity_pricing.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/loader.py -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/minute_bars.py -> build/lib.linux-x86_64-3.7/zipline/data
#   creating build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/labelarray.py -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/__init__.py -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/normalize.py -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/adjusted_array.py -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/quantiles.py -> build/lib.linux-x86_64-3.7/zipline/lib
#   creating build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/run_algo.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/pool.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/compat.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/enum.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/simfactory.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/sentinel.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/cli.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/sharedoc.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/tradingcalendar.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/api_support.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/dummy.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/range.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/calendars.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/numpy_utils.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/__init__.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/cache.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/algo_instance.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/input_validation.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/paths.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/data.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/pandas_utils.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/exploding_object.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/functional.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/events.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/context_tricks.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/classproperty.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/sqlite_utils.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/math_utils.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/argcheck.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/preprocess.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/metautils.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/final.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/security_list.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/deprecate.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/memoize.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/date_utils.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   copying zipline/utils/factory.py -> build/lib.linux-x86_64-3.7/zipline/utils
#   creating build/lib.linux-x86_64-3.7/zipline/sources
#   copying zipline/sources/test_source.py -> build/lib.linux-x86_64-3.7/zipline/sources
#   copying zipline/sources/__init__.py -> build/lib.linux-x86_64-3.7/zipline/sources
#   copying zipline/sources/benchmark_source.py -> build/lib.linux-x86_64-3.7/zipline/sources
#   copying zipline/sources/requests_csv.py -> build/lib.linux-x86_64-3.7/zipline/sources
#   creating build/lib.linux-x86_64-3.7/zipline/pipeline/classifiers
#   copying zipline/pipeline/classifiers/__init__.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/classifiers
#   copying zipline/pipeline/classifiers/classifier.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/classifiers
#   creating build/lib.linux-x86_64-3.7/zipline/pipeline/factors
#   copying zipline/pipeline/factors/basic.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/factors
#   copying zipline/pipeline/factors/technical.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/factors
#   copying zipline/pipeline/factors/__init__.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/factors
#   copying zipline/pipeline/factors/events.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/factors
#   copying zipline/pipeline/factors/statistical.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/factors
#   copying zipline/pipeline/factors/factor.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/factors
#   creating build/lib.linux-x86_64-3.7/zipline/pipeline/data
#   copying zipline/pipeline/data/__init__.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/data
#   copying zipline/pipeline/data/testing.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/data
#   copying zipline/pipeline/data/equity_pricing.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/data
#   copying zipline/pipeline/data/dataset.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/data
#   creating build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   copying zipline/pipeline/loaders/frame.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   copying zipline/pipeline/loaders/synthetic.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   copying zipline/pipeline/loaders/base.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   copying zipline/pipeline/loaders/equity_pricing_loader.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   copying zipline/pipeline/loaders/__init__.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   copying zipline/pipeline/loaders/testing.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   copying zipline/pipeline/loaders/events.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   copying zipline/pipeline/loaders/utils.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   copying zipline/pipeline/loaders/earnings_estimates.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders
#   creating build/lib.linux-x86_64-3.7/zipline/pipeline/filters
#   copying zipline/pipeline/filters/filter.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/filters
#   copying zipline/pipeline/filters/__init__.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/filters
#   copying zipline/pipeline/filters/smoothing.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/filters
#   creating build/lib.linux-x86_64-3.7/zipline/pipeline/loaders/blaze
#   copying zipline/pipeline/loaders/blaze/__init__.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders/blaze
#   copying zipline/pipeline/loaders/blaze/core.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders/blaze
#   copying zipline/pipeline/loaders/blaze/events.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders/blaze
#   copying zipline/pipeline/loaders/blaze/estimates.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders/blaze
#   copying zipline/pipeline/loaders/blaze/utils.py -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders/blaze
#   creating build/lib.linux-x86_64-3.7/zipline/finance/blotter
#   copying zipline/finance/blotter/__init__.py -> build/lib.linux-x86_64-3.7/zipline/finance/blotter
#   copying zipline/finance/blotter/blotter.py -> build/lib.linux-x86_64-3.7/zipline/finance/blotter
#   copying zipline/finance/blotter/simulation_blotter.py -> build/lib.linux-x86_64-3.7/zipline/finance/blotter
#   creating build/lib.linux-x86_64-3.7/zipline/finance/metrics
#   copying zipline/finance/metrics/metric.py -> build/lib.linux-x86_64-3.7/zipline/finance/metrics
#   copying zipline/finance/metrics/__init__.py -> build/lib.linux-x86_64-3.7/zipline/finance/metrics
#   copying zipline/finance/metrics/core.py -> build/lib.linux-x86_64-3.7/zipline/finance/metrics
#   copying zipline/finance/metrics/tracker.py -> build/lib.linux-x86_64-3.7/zipline/finance/metrics
#   creating build/lib.linux-x86_64-3.7/zipline/data/bundles
#   copying zipline/data/bundles/quandl.py -> build/lib.linux-x86_64-3.7/zipline/data/bundles
#   copying zipline/data/bundles/avocados.py -> build/lib.linux-x86_64-3.7/zipline/data/bundles
#   copying zipline/data/bundles/__init__.py -> build/lib.linux-x86_64-3.7/zipline/data/bundles
#   copying zipline/data/bundles/core.py -> build/lib.linux-x86_64-3.7/zipline/data/bundles
#   copying zipline/data/bundles/csvdir.py -> build/lib.linux-x86_64-3.7/zipline/data/bundles
#   copying zipline/api.pyi -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/_protocol.pyx -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/_protocol.pxd -> build/lib.linux-x86_64-3.7/zipline
#   copying zipline/gens/sim_engine.pyx -> build/lib.linux-x86_64-3.7/zipline/gens
#   copying zipline/assets/continuous_futures.pyx -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/_assets.pyx -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/assets/_assets.pxd -> build/lib.linux-x86_64-3.7/zipline/assets
#   copying zipline/finance/_finance_ext.pyx -> build/lib.linux-x86_64-3.7/zipline/finance
#   copying zipline/data/_equities.pyx -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/_minute_bar_internal.pyx -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/_resample.pyx -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/data/_adjustments.pyx -> build/lib.linux-x86_64-3.7/zipline/data
#   copying zipline/lib/_float64window.pyx -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/adjustment.pyx -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/_factorize.pyx -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/_labelwindow.pyx -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/rank.pyx -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/_uint8window.pyx -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/_int64window.pyx -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/_windowtemplate.pxi -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/lib/adjustment.pxd -> build/lib.linux-x86_64-3.7/zipline/lib
#   copying zipline/pipeline/loaders/blaze/_core.pyx -> build/lib.linux-x86_64-3.7/zipline/pipeline/loaders/blaze
#   UPDATING build/lib.linux-x86_64-3.7/zipline/_version.py
#   set build/lib.linux-x86_64-3.7/zipline/_version.py to '1.3.0'
#   running build_ext
#   skipping 'zipline/assets/_assets.c' Cython extension (up-to-date)
#   skipping 'zipline/assets/continuous_futures.c' Cython extension (up-to-date)
#   skipping 'zipline/lib/adjustment.c' Cython extension (up-to-date)
#   skipping 'zipline/lib/_factorize.c' Cython extension (up-to-date)
#   skipping 'zipline/lib/_float64window.c' Cython extension (up-to-date)
#   skipping 'zipline/lib/_int64window.c' Cython extension (up-to-date)
#   skipping 'zipline/lib/_int64window.c' Cython extension (up-to-date)
#   skipping 'zipline/lib/_uint8window.c' Cython extension (up-to-date)
#   skipping 'zipline/lib/_labelwindow.c' Cython extension (up-to-date)
#   skipping 'zipline/lib/rank.c' Cython extension (up-to-date)
#   skipping 'zipline/data/_equities.c' Cython extension (up-to-date)
#   skipping 'zipline/data/_adjustments.c' Cython extension (up-to-date)
#   skipping 'zipline/_protocol.c' Cython extension (up-to-date)
#   skipping 'zipline/finance/_finance_ext.c' Cython extension (up-to-date)
#   skipping 'zipline/gens/sim_engine.c' Cython extension (up-to-date)
#   skipping 'zipline/data/_minute_bar_internal.c' Cython extension (up-to-date)
#   skipping 'zipline/data/_resample.c' Cython extension (up-to-date)
#   skipping 'zipline/pipeline/loaders/blaze/_core.c' Cython extension (up-to-date)
#   building 'zipline.assets._assets' extension
#   creating build/temp.linux-x86_64-3.7
#   creating build/temp.linux-x86_64-3.7/zipline
#   creating build/temp.linux-x86_64-3.7/zipline/assets
#   gcc -pthread -B /opt/conda/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/conda/lib/python3.7/site-packages/numpy/core/include -I/opt/conda/include/python3.7m -c zipline/assets/_assets.c -o build/temp.linux-x86_64-3.7/zipline/assets/_assets.o
#   In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1832:0,
#                    from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                    from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                    from zipline/assets/_assets.c:525:
#   /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    #warning "Using deprecated NumPy API, disable it with " \
#     ^~~~~~~
#   zipline/assets/_assets.c: In function ‘__Pyx__ExceptionSave’:
#   zipline/assets/_assets.c:10488:21: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        *type = tstate->exc_type;
#                        ^~~~~~~~
#                        curexc_type
#   zipline/assets/_assets.c:10489:22: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        *value = tstate->exc_value;
#                         ^~~~~~~~~
#                         curexc_value
#   zipline/assets/_assets.c:10490:19: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        *tb = tstate->exc_traceback;
#                      ^~~~~~~~~~~~~
#                      curexc_traceback
#   zipline/assets/_assets.c: In function ‘__Pyx__ExceptionReset’:
#   zipline/assets/_assets.c:10497:24: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   zipline/assets/_assets.c:10498:25: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   zipline/assets/_assets.c:10499:22: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   zipline/assets/_assets.c:10500:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tstate->exc_type = type;
#                ^~~~~~~~
#                curexc_type
#   zipline/assets/_assets.c:10501:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tstate->exc_value = value;
#                ^~~~~~~~~
#                curexc_value
#   zipline/assets/_assets.c:10502:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tstate->exc_traceback = tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   zipline/assets/_assets.c: In function ‘__Pyx__GetException’:
#   zipline/assets/_assets.c:10572:24: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   zipline/assets/_assets.c:10573:25: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   zipline/assets/_assets.c:10574:22: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   zipline/assets/_assets.c:10575:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tstate->exc_type = local_type;
#                ^~~~~~~~
#                curexc_type
#   zipline/assets/_assets.c:10576:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tstate->exc_value = local_value;
#                ^~~~~~~~~
#                curexc_value
#   zipline/assets/_assets.c:10577:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tstate->exc_traceback = local_tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for zipline
#   Running setup.py clean for zipline
#   Building wheel for cyordereddict (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-vombu9hl/cyordereddict/setup.py'"'"'; __file__='"'"'/tmp/pip-install-vombu9hl/cyordereddict/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-0jmnl8na
#        cwd: /tmp/pip-install-vombu9hl/cyordereddict/
#   Complete output (49 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.7
#   creating build/lib.linux-x86_64-3.7/cyordereddict
#   copying python3/cyordereddict/__init__.py -> build/lib.linux-x86_64-3.7/cyordereddict
#   copying python3/cyordereddict/_version.py -> build/lib.linux-x86_64-3.7/cyordereddict
#   creating build/lib.linux-x86_64-3.7/cyordereddict/benchmark
#   copying python3/cyordereddict/benchmark/benchmark.py -> build/lib.linux-x86_64-3.7/cyordereddict/benchmark
#   copying python3/cyordereddict/benchmark/__init__.py -> build/lib.linux-x86_64-3.7/cyordereddict/benchmark
#   copying python3/cyordereddict/benchmark/magic_timeit.py -> build/lib.linux-x86_64-3.7/cyordereddict/benchmark
#   creating build/lib.linux-x86_64-3.7/cyordereddict/test
#   copying python3/cyordereddict/test/test_ordereddict.py -> build/lib.linux-x86_64-3.7/cyordereddict/test
#   copying python3/cyordereddict/test/test_cyordereddict.py -> build/lib.linux-x86_64-3.7/cyordereddict/test
#   copying python3/cyordereddict/test/__init__.py -> build/lib.linux-x86_64-3.7/cyordereddict/test
#   copying python3/cyordereddict/test/_mapping_tests.py -> build/lib.linux-x86_64-3.7/cyordereddict/test
#   running build_ext
#   building 'cyordereddict._cyordereddict' extension
#   creating build/temp.linux-x86_64-3.7
#   creating build/temp.linux-x86_64-3.7/python3
#   creating build/temp.linux-x86_64-3.7/python3/cyordereddict
#   gcc -pthread -B /opt/conda/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/conda/include/python3.7m -c python3/cyordereddict/_cyordereddict.c -o build/temp.linux-x86_64-3.7/python3/cyordereddict/_cyordereddict.o
#   python3/cyordereddict/_cyordereddict.c: In function ‘__Pyx_ExceptionSwap’:
#   python3/cyordereddict/_cyordereddict.c:7481:24: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   python3/cyordereddict/_cyordereddict.c:7482:25: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   python3/cyordereddict/_cyordereddict.c:7483:22: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   python3/cyordereddict/_cyordereddict.c:7484:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tstate->exc_type = *type;
#                ^~~~~~~~
#                curexc_type
#   python3/cyordereddict/_cyordereddict.c:7485:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tstate->exc_value = *value;
#                ^~~~~~~~~
#                curexc_value
#   python3/cyordereddict/_cyordereddict.c:7486:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tstate->exc_traceback = *tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for cyordereddict
#   Running setup.py clean for cyordereddict
#   Building wheel for bcolz (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-vombu9hl/bcolz/setup.py'"'"'; __file__='"'"'/tmp/pip-install-vombu9hl/bcolz/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-cigqg9la
#        cwd: /tmp/pip-install-vombu9hl/bcolz/
#   Complete output (111 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.7
#   creating build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/attrs.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/ctable.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/py2help_tests.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/toplevel.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/__init__.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/arrayprint.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/defaults.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/chunked_eval.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/py2help.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/utils.py -> build/lib.linux-x86_64-3.7/bcolz
#   copying bcolz/version.py -> build/lib.linux-x86_64-3.7/bcolz
#   creating build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/tests/test_ctable.py -> build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/tests/test_ndcarray.py -> build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/tests/__init__.py -> build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/tests/all.py -> build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/tests/test_attrs.py -> build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/tests/test_carray.py -> build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/tests/test_carray_objects.py -> build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/tests/common.py -> build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/tests/test_queries.py -> build/lib.linux-x86_64-3.7/bcolz/tests
#   copying bcolz/carray_ext.pxd -> build/lib.linux-x86_64-3.7/bcolz
#   running build_ext
#   skipping 'bcolz/carray_ext.c' Cython extension (up-to-date)
#   building 'bcolz.carray_ext' extension
#   creating build/temp.linux-x86_64-3.7
#   creating build/temp.linux-x86_64-3.7/bcolz
#   creating build/temp.linux-x86_64-3.7/c-blosc
#   creating build/temp.linux-x86_64-3.7/c-blosc/blosc
#   creating build/temp.linux-x86_64-3.7/c-blosc/internal-complibs
#   creating build/temp.linux-x86_64-3.7/c-blosc/internal-complibs/lz4-r119
#   creating build/temp.linux-x86_64-3.7/c-blosc/internal-complibs/snappy-1.1.1
#   creating build/temp.linux-x86_64-3.7/c-blosc/internal-complibs/zlib-1.2.8
#   gcc -pthread -B /opt/conda/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/lz4-r119 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -I/opt/conda/lib/python3.7/site-packages/numpy/core/include -I/opt/conda/include/python3.7m -c bcolz/carray_ext.c -o build/temp.linux-x86_64-3.7/bcolz/carray_ext.o
#   In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1832:0,
#                    from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                    from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                    from bcolz/carray_ext.c:242:
#   /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    #warning "Using deprecated NumPy API, disable it with " \
#     ^~~~~~~
#   bcolz/carray_ext.c: In function ‘__Pyx_ExceptionSave’:
#   bcolz/carray_ext.c:41286:21: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        *type = tstate->exc_type;
#                        ^~~~~~~~
#                        curexc_type
#   bcolz/carray_ext.c:41287:22: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        *value = tstate->exc_value;
#                         ^~~~~~~~~
#                         curexc_value
#   bcolz/carray_ext.c:41288:19: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        *tb = tstate->exc_traceback;
#                      ^~~~~~~~~~~~~
#                      curexc_traceback
#   bcolz/carray_ext.c: In function ‘__Pyx_ExceptionReset’:
#   bcolz/carray_ext.c:41300:24: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   bcolz/carray_ext.c:41301:25: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   bcolz/carray_ext.c:41302:22: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   bcolz/carray_ext.c:41303:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tstate->exc_type = type;
#                ^~~~~~~~
#                curexc_type
#   bcolz/carray_ext.c:41304:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tstate->exc_value = value;
#                ^~~~~~~~~
#                curexc_value
#   bcolz/carray_ext.c:41305:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tstate->exc_traceback = tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   bcolz/carray_ext.c: In function ‘__Pyx_GetException’:
#   bcolz/carray_ext.c:41348:24: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   bcolz/carray_ext.c:41349:25: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   bcolz/carray_ext.c:41350:22: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   bcolz/carray_ext.c:41351:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#        tstate->exc_type = local_type;
#                ^~~~~~~~
#                curexc_type
#   bcolz/carray_ext.c:41352:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#        tstate->exc_value = local_value;
#                ^~~~~~~~~
#                curexc_value
#   bcolz/carray_ext.c:41353:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#        tstate->exc_traceback = local_tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for bcolz
#   Running setup.py clean for bcolz
# Failed to build zipline cyordereddict bcolz
# ERROR: zipline 1.3.0 has requirement pandas<=0.22,>=0.18.1, but you'll have pandas 1.0.3 which is incompatible.
# Installing collected packages: cyordereddict, bottleneck, contextlib2, networkx, numexpr, bcolz, click, toolz, multipledispatch, Mako, sqlalchemy, python-editor, alembic, sortedcontainers, intervaltree, lru-dict, empyrical, tables, trading-calendars, zipline
#     Running setup.py install for cyordereddict ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-vombu9hl/cyordereddict/setup.py'"'"'; __file__='"'"'/tmp/pip-install-vombu9hl/cyordereddict/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-5zf27h3z/install-record.txt --single-version-externally-managed --compile --install-headers /opt/conda/include/python3.7m/cyordereddict
#          cwd: /tmp/pip-install-vombu9hl/cyordereddict/
#     Complete output (49 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.7
#     creating build/lib.linux-x86_64-3.7/cyordereddict
#     copying python3/cyordereddict/__init__.py -> build/lib.linux-x86_64-3.7/cyordereddict
#     copying python3/cyordereddict/_version.py -> build/lib.linux-x86_64-3.7/cyordereddict
#     creating build/lib.linux-x86_64-3.7/cyordereddict/benchmark
#     copying python3/cyordereddict/benchmark/benchmark.py -> build/lib.linux-x86_64-3.7/cyordereddict/benchmark
#     copying python3/cyordereddict/benchmark/__init__.py -> build/lib.linux-x86_64-3.7/cyordereddict/benchmark
#     copying python3/cyordereddict/benchmark/magic_timeit.py -> build/lib.linux-x86_64-3.7/cyordereddict/benchmark
#     creating build/lib.linux-x86_64-3.7/cyordereddict/test
#     copying python3/cyordereddict/test/test_ordereddict.py -> build/lib.linux-x86_64-3.7/cyordereddict/test
#     copying python3/cyordereddict/test/test_cyordereddict.py -> build/lib.linux-x86_64-3.7/cyordereddict/test
#     copying python3/cyordereddict/test/__init__.py -> build/lib.linux-x86_64-3.7/cyordereddict/test
#     copying python3/cyordereddict/test/_mapping_tests.py -> build/lib.linux-x86_64-3.7/cyordereddict/test
#     running build_ext
#     building 'cyordereddict._cyordereddict' extension
#     creating build/temp.linux-x86_64-3.7
#     creating build/temp.linux-x86_64-3.7/python3
#     creating build/temp.linux-x86_64-3.7/python3/cyordereddict
#     gcc -pthread -B /opt/conda/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/opt/conda/include/python3.7m -c python3/cyordereddict/_cyordereddict.c -o build/temp.linux-x86_64-3.7/python3/cyordereddict/_cyordereddict.o
#     python3/cyordereddict/_cyordereddict.c: In function ‘__Pyx_ExceptionSwap’:
#     python3/cyordereddict/_cyordereddict.c:7481:24: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#          tmp_type = tstate->exc_type;
#                             ^~~~~~~~
#                             curexc_type
#     python3/cyordereddict/_cyordereddict.c:7482:25: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#          tmp_value = tstate->exc_value;
#                              ^~~~~~~~~
#                              curexc_value
#     python3/cyordereddict/_cyordereddict.c:7483:22: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#          tmp_tb = tstate->exc_traceback;
#                           ^~~~~~~~~~~~~
#                           curexc_traceback
#     python3/cyordereddict/_cyordereddict.c:7484:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_type’; did you mean ‘curexc_type’?
#          tstate->exc_type = *type;
#                  ^~~~~~~~
#                  curexc_type
#     python3/cyordereddict/_cyordereddict.c:7485:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#          tstate->exc_value = *value;
#                  ^~~~~~~~~
#                  curexc_value
#     python3/cyordereddict/_cyordereddict.c:7486:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#          tstate->exc_traceback = *tb;
#                  ^~~~~~~~~~~~~
#                  curexc_traceback
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /opt/conda/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-vombu9hl/cyordereddict/setup.py'"'"'; __file__='"'"'/tmp/pip-install-vombu9hl/cyordereddict/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-5zf27h3z/install-record.txt --single-version-externally-managed --compile --install-headers /opt/conda/include/python3.7m/cyordereddict Check the logs for full command output.

# %% [markdown]
# ### Load Packages

# %%
import pandas as pd
import numpy as np
import helper
import project_helper
import project_tests
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Market Data
# ### Load Data
# While using real data will give you hands on experience, it's doesn't cover all the topics we try to condense in one project. We'll solve this by creating new stocks. We've create a scenario where companies mining [Terbium](https://en.wikipedia.org/wiki/Terbium) are making huge profits. All the companies in this sector of the market are made up. They represent a sector with large growth that will be used for demonstration latter in this project.

# %%
df_original = pd.read_csv('../data/eod-quotemedia.csv', parse_dates=['date'], index_col=False)

# Add TB sector to the market
df = df_original
df = pd.concat([df] + project_helper.generate_tb_sector(df[df['ticker'] == 'AAPL']['date']), ignore_index=True)

close = df.reset_index().pivot(index='date', columns='ticker', values='adj_close')
high = df.reset_index().pivot(index='date', columns='ticker', values='adj_high')
low = df.reset_index().pivot(index='date', columns='ticker', values='adj_low')

print('Loaded Data')
# Out:
# Loaded Data

# %% [markdown]
# ### View Data
# To see what one of these 2-d matrices looks like, let's take a look at the closing prices matrix.

# %%
close
# Out:
# ticker               A         AAL          AAP         AAPL        ABBV  \
# date
# 2013-07-01 29.99418563 16.17609308  81.13821681  53.10917319 34.92447839
# 2013-07-02 29.65013670 15.81983388  80.72207258  54.31224742 35.42807578
# 2013-07-03 29.70518453 16.12794994  81.23729877  54.61204262 35.44486235
# 2013-07-05 30.43456826 16.21460758  81.82188233  54.17338125 35.85613355
# 2013-07-08 30.52402098 16.31089385  82.95141667  53.86579916 36.66188936
# ...                ...         ...          ...          ...         ...
# 2017-06-26 58.57854478 48.36234805 121.52159207 143.57270901 70.35520945
# 2017-06-27 58.22256443 48.08474540 121.69121741 141.51491885 70.01668424
# 2017-06-28 58.73675827 48.82832394 116.45278767 143.58255490 70.52930812
# 2017-06-29 58.27398382 49.19515602 115.79424221 141.46568942 70.10373358
# 2017-06-30 58.77942143 49.88916265 116.33305213 141.80044954 70.13275003
#
# ticker             ABC         ABT          ACN         ADBE         ADI  ...  \
# date                                                                      ...
# 2013-07-01 50.86319750 31.42538772  64.69409505  46.23500000 39.91336014  ...
# 2013-07-02 50.69676639 31.27288084  64.71204071  46.03000000 39.86057632  ...
# 2013-07-03 50.93716689 30.72565028  65.21451912  46.42000000 40.18607651  ...
# 2013-07-05 51.37173702 31.32670680  66.07591068  47.00000000 40.65233352  ...
# 2013-07-08 52.03746147 31.76628544  66.82065546  46.62500000 40.25645492  ...
# ...                ...         ...          ...          ...         ...  ...
# 2017-06-26 94.31043377 47.95227368 120.09101209 144.96000000 78.92677572  ...
# 2017-06-27 93.85848253 47.71697322 119.94376955 142.54000000 76.54633554  ...
# 2017-06-28 94.69360982 47.53069368 121.46527575 143.81000000 77.58471685  ...
# 2017-06-29 94.08445815 47.77579833 120.72906307 141.24000000 76.15449354  ...
# 2017-06-30 92.87597984 47.65814810 121.40637874 141.44000000 76.21326984  ...
#
# ticker              XL        XLNX         XOM        XRAY         XRX  \
# date
# 2013-07-01 27.66879066 35.28892781 76.32080247 40.02387348 22.10666494
# 2013-07-02 27.54228410 35.05903252 76.60816761 39.96552964 22.08273998
# 2013-07-03 27.33445191 35.28008569 76.65042719 40.00442554 22.20236479
# 2013-07-05 27.69589920 35.80177117 77.39419581 40.67537968 22.58516418
# 2013-07-08 27.98505704 35.20050655 77.96892611 40.64620776 22.48946433
# ...                ...         ...         ...         ...         ...
# 2017-06-26 42.76892496 65.99587865 78.12543603 63.56673975 27.95461459
# 2017-06-27 43.14151074 63.78164638 78.00041995 63.92391201 27.75350225
# 2017-06-28 43.30819385 64.67321778 78.40431807 64.82428373 28.28980181
# 2017-06-29 43.27877918 62.88027749 77.60613845 64.10898129 28.12560699
# 2017-06-30 42.94541296 63.01744232 77.63498832 64.41695873 27.74892476
#
# ticker             XYL         YUM          ZBH        ZION         ZTS
# date
# 2013-07-01 25.75338607 45.48038323  71.89882693 27.85858718 29.44789315
# 2013-07-02 25.61367511 45.40266113  72.93417195 28.03893238 28.57244125
# 2013-07-03 25.73475794 46.06329899  72.30145844 28.18131017 28.16838652
# 2013-07-05 26.06075017 46.41304845  73.16424628 29.39626730 29.02459772
# 2013-07-08 26.22840332 46.95062632  73.89282298 29.57661249 29.76536472
# ...                ...         ...          ...         ...         ...
# 2017-06-26 54.05749897 73.49934641 127.97264293 41.75554533 62.43009343
# 2017-06-27 53.87954816 72.74212810 127.16946735 41.95278457 62.46990854
# 2017-06-28 54.34419748 72.91914017 127.42727680 42.37684891 62.65903032
# 2017-06-29 54.27499439 72.23075989 126.81250043 43.38276899 62.21111032
# 2017-06-30 54.79896064 72.53561401 127.31820357 43.30387330 62.09166499
#
# [1009 rows x 519 columns]

# %% [markdown]
# ### Stock Example
# Let's see what a single stock looks like from the closing prices. For this example and future display examples in this project, we'll use Apple's stock (AAPL). If we tried to graph all the stocks, it would be too much information.

# %%
apple_ticker = 'AAPL'
project_helper.plot_stock(close[apple_ticker], '{} Stock'.format(apple_ticker))
# Out:
# <div>
#
#
#             <div id="89ac2cb3-48f4-48e5-acdb-8e99c84eefb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("89ac2cb3-48f4-48e5-acdb-8e99c84eefb7")) {
#                     Plotly.newPlot(
#                         '89ac2cb3-48f4-48e5-acdb-8e99c84eefb7',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013-10-02T00:00:00", "2013-10-03T00:00:00", "2013-10-04T00:00:00", "2013-10-07T00:00:00", "2013-10-08T00:00:00", "2013-10-09T00:00:00", "2013-10-10T00:00:00", "2013-10-11T00:00:00", "2013-10-14T00:00:00", "2013-10-15T00:00:00", "2013-10-16T00:00:00", "2013-10-17T00:00:00", "2013-10-18T00:00:00", "2013-10-21T00:00:00", "2013-10-22T00:00:00", "2013-10-23T00:00:00", "2013-10-24T00:00:00", "2013-10-25T00:00:00", "2013-10-28T00:00:00", "2013-10-29T00:00:00", "2013-10-30T00:00:00", "2013-10-31T00:00:00", "2013-11-01T00:00:00", "2013-11-04T00:00:00", "2013-11-05T00:00:00", "2013-11-06T00:00:00", "2013-11-07T00:00:00", "2013-11-08T00:00:00", "2013-11-11T00:00:00", "2013-11-12T00:00:00", "2013-11-13T00:00:00", "2013-11-14T00:00:00", "2013-11-15T00:00:00", "2013-11-18T00:00:00", "2013-11-19T00:00:00", "2013-11-20T00:00:00", "2013-11-21T00:00:00", "2013-11-22T00:00:00", "2013-11-25T00:00:00", "2013-11-26T00:00:00", "2013-11-27T00:00:00", "2013-11-29T00:00:00", "2013-12-02T00:00:00", "2013-12-03T00:00:00", "2013-12-04T00:00:00", "2013-12-05T00:00:00", "2013-12-06T00:00:00", "2013-12-09T00:00:00", "2013-12-10T00:00:00", "2013-12-11T00:00:00", "2013-12-12T00:00:00", "2013-12-13T00:00:00", "2013-12-16T00:00:00", "2013-12-17T00:00:00", "2013-12-18T00:00:00", "2013-12-19T00:00:00", "2013-12-20T00:00:00", "2013-12-23T00:00:00", "2013-12-24T00:00:00", "2013-12-26T00:00:00", "2013-12-27T00:00:00", "2013-12-30T00:00:00", "2013-12-31T00:00:00", "2014-01-02T00:00:00", "2014-01-03T00:00:00", "2014-01-06T00:00:00", "2014-01-07T00:00:00", "2014-01-08T00:00:00", "2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00 ...

# %% [markdown]
# ## The Alpha Research Process
#
# In this project you will code and evaluate a "breakout" signal. It is important to understand where these steps fit in the alpha research workflow. The signal-to-noise ratio in trading signals is very low and, as such, it is very easy to fall into the trap of _overfitting_ to noise. It is therefore inadvisable to jump right into signal coding. To help mitigate overfitting, it is best to start with a general observation and hypothesis; i.e., you should be able to answer the following question _before_ you touch any data:
#
# > What feature of markets or investor behaviour would lead to a persistent anomaly that my signal will try to use?
#
# Ideally the assumptions behind the hypothesis will be testable _before_ you actually code and evaluate the signal itself. The workflow therefore is as follows:
#
# ![image](images/alpha_steps.png)
#
# In this project, we assume that the first three steps area done ("observe & research", "form hypothesis", "validate hypothesis"). The hypothesis you'll be using for this project is the following:
# - In the absence of news or significant investor trading interest, stocks oscillate in a range.
# - Traders seek to capitalize on this range-bound behaviour periodically by selling/shorting at the top of the range and buying/covering at the bottom of the range. This behaviour reinforces the existence of the range.
# - When stocks break out of the range, due to, e.g., a significant news release or from market pressure from a large investor:
#     - the liquidity traders who have been providing liquidity at the bounds of the range seek to cover their positions to mitigate losses, thus magnifying the move out of the range, _and_
#     - the move out of the range attracts other investor interest; these investors, due to the behavioural bias of _herding_ (e.g., [Herd Behavior](https://www.investopedia.com/university/behavioral_finance/behavioral8.asp)) build positions which favor continuation of the trend.
#
#
# Using this hypothesis, let start coding..
# ## Compute the Highs and Lows in a Window
# You'll use the price highs and lows as an indicator for the breakout strategy. In this section, implement `get_high_lows_lookback` to get the maximum high price and minimum low price over a window of days. The variable `lookback_days` contains the number of days to look in the past. Make sure this doesn't include the current day.

# %%
def get_high_lows_lookback(high, low, lookback_days):
    """
    Get the highs and lows in a lookback window.
    
    Parameters
    ----------
    high : DataFrame
        High price for each ticker and date
    low : DataFrame
        Low price for each ticker and date
    lookback_days : int
        The number of days to look back
    
    Returns
    -------
    lookback_high : DataFrame
        Lookback high price for each ticker and date
    lookback_low : DataFrame
        Lookback low price for each ticker and date
    """
    #TODO: Implement function
    return high.rolling(lookback_days).max().shift(1), low.rolling(lookback_days).min().shift(1)

project_tests.test_get_high_lows_lookback(get_high_lows_lookback)
# Out:
# Tests Passed

# %% [markdown]
# ### View Data
# Let's use your implementation of `get_high_lows_lookback` to get the highs and lows for the past 50 days and compare it to it their respective stock.  Just like last time, we'll use Apple's stock as the example to look at.

# %%
lookback_days = 50
lookback_high, lookback_low = get_high_lows_lookback(high, low, lookback_days)
project_helper.plot_high_low(
    close[apple_ticker],
    lookback_high[apple_ticker],
    lookback_low[apple_ticker],
    'High and Low of {} Stock'.format(apple_ticker))
# Out:
# <div>
#
#
#             <div id="e3951fe0-d23d-4964-8e57-d3a2bcff13c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e3951fe0-d23d-4964-8e57-d3a2bcff13c7")) {
#                     Plotly.newPlot(
#                         'e3951fe0-d23d-4964-8e57-d3a2bcff13c7',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013-10-02T00:00:00", "2013-10-03T00:00:00", "2013-10-04T00:00:00", "2013-10-07T00:00:00", "2013-10-08T00:00:00", "2013-10-09T00:00:00", "2013-10-10T00:00:00", "2013-10-11T00:00:00", "2013-10-14T00:00:00", "2013-10-15T00:00:00", "2013-10-16T00:00:00", "2013-10-17T00:00:00", "2013-10-18T00:00:00", "2013-10-21T00:00:00", "2013-10-22T00:00:00", "2013-10-23T00:00:00", "2013-10-24T00:00:00", "2013-10-25T00:00:00", "2013-10-28T00:00:00", "2013-10-29T00:00:00", "2013-10-30T00:00:00", "2013-10-31T00:00:00", "2013-11-01T00:00:00", "2013-11-04T00:00:00", "2013-11-05T00:00:00", "2013-11-06T00:00:00", "2013-11-07T00:00:00", "2013-11-08T00:00:00", "2013-11-11T00:00:00", "2013-11-12T00:00:00", "2013-11-13T00:00:00", "2013-11-14T00:00:00", "2013-11-15T00:00:00", "2013-11-18T00:00:00", "2013-11-19T00:00:00", "2013-11-20T00:00:00", "2013-11-21T00:00:00", "2013-11-22T00:00:00", "2013-11-25T00:00:00", "2013-11-26T00:00:00", "2013-11-27T00:00:00", "2013-11-29T00:00:00", "2013-12-02T00:00:00", "2013-12-03T00:00:00", "2013-12-04T00:00:00", "2013-12-05T00:00:00", "2013-12-06T00:00:00", "2013-12-09T00:00:00", "2013-12-10T00:00:00", "2013-12-11T00:00:00", "2013-12-12T00:00:00", "2013-12-13T00:00:00", "2013-12-16T00:00:00", "2013-12-17T00:00:00", "2013-12-18T00:00:00", "2013-12-19T00:00:00", "2013-12-20T00:00:00", "2013-12-23T00:00:00", "2013-12-24T00:00:00", "2013-12-26T00:00:00", "2013-12-27T00:00:00", "2013-12-30T00:00:00", "2013-12-31T00:00:00", "2014-01-02T00:00:00", "2014-01-03T00:00:00", "2014-01-06T00:00:00", "2014-01-07T00:00:00", "2014-01-08T00:00:00", "2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00 ...

# %% [markdown]
# ## Compute Long and Short Signals
# Using the generated indicator of highs and lows, create long and short signals using a breakout strategy. Implement `get_long_short` to generate the following signals:
#
# | Signal | Condition |
# |----|------|
# | -1 | Low > Close Price |
# | 1  | High < Close Price |
# | 0  | Otherwise |
#
# In this chart, **Close Price** is the `close` parameter. **Low** and **High** are the values generated from `get_high_lows_lookback`, the `lookback_high` and `lookback_low` parameters.

# %%
def get_long_short(close, lookback_high, lookback_low):
    """
    Generate the signals long, short, and do nothing.
    
    Parameters
    ----------
    close : DataFrame
        Close price for each ticker and date
    lookback_high : DataFrame
        Lookback high price for each ticker and date
    lookback_low : DataFrame
        Lookback low price for each ticker and date
    
    Returns
    -------
    long_short : DataFrame
        The long, short, and do nothing signals for each ticker and date
    """
    #TODO: Implement function
    long_short = close.copy()
    long_short.where(close > lookback_low, -1, inplace=True)
    long_short.where(close < lookback_high, 1, inplace=True)
    long_short.where((close < lookback_low) | (close > lookback_high), 0, inplace=True)
    long_short = long_short.astype('int64')
    return long_short

project_tests.test_get_long_short(get_long_short)
# Out:
# Tests Passed

# %% [markdown]
# ### View Data
# Let's compare the signals you generated against the close prices. This chart will show a lot of signals. Too many in fact. We'll talk about filtering the redundant signals in the next problem.

# %%
signal = get_long_short(close, lookback_high, lookback_low)
project_helper.plot_signal(
    close[apple_ticker],
    signal[apple_ticker],
    'Long and Short of {} Stock'.format(apple_ticker))
# Out:
# <div>
#
#
#             <div id="1d651301-0c9f-4e7a-99f2-47f9471be9e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1d651301-0c9f-4e7a-99f2-47f9471be9e7")) {
#                     Plotly.newPlot(
#                         '1d651301-0c9f-4e7a-99f2-47f9471be9e7',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013-10-02T00:00:00", "2013-10-03T00:00:00", "2013-10-04T00:00:00", "2013-10-07T00:00:00", "2013-10-08T00:00:00", "2013-10-09T00:00:00", "2013-10-10T00:00:00", "2013-10-11T00:00:00", "2013-10-14T00:00:00", "2013-10-15T00:00:00", "2013-10-16T00:00:00", "2013-10-17T00:00:00", "2013-10-18T00:00:00", "2013-10-21T00:00:00", "2013-10-22T00:00:00", "2013-10-23T00:00:00", "2013-10-24T00:00:00", "2013-10-25T00:00:00", "2013-10-28T00:00:00", "2013-10-29T00:00:00", "2013-10-30T00:00:00", "2013-10-31T00:00:00", "2013-11-01T00:00:00", "2013-11-04T00:00:00", "2013-11-05T00:00:00", "2013-11-06T00:00:00", "2013-11-07T00:00:00", "2013-11-08T00:00:00", "2013-11-11T00:00:00", "2013-11-12T00:00:00", "2013-11-13T00:00:00", "2013-11-14T00:00:00", "2013-11-15T00:00:00", "2013-11-18T00:00:00", "2013-11-19T00:00:00", "2013-11-20T00:00:00", "2013-11-21T00:00:00", "2013-11-22T00:00:00", "2013-11-25T00:00:00", "2013-11-26T00:00:00", "2013-11-27T00:00:00", "2013-11-29T00:00:00", "2013-12-02T00:00:00", "2013-12-03T00:00:00", "2013-12-04T00:00:00", "2013-12-05T00:00:00", "2013-12-06T00:00:00", "2013-12-09T00:00:00", "2013-12-10T00:00:00", "2013-12-11T00:00:00", "2013-12-12T00:00:00", "2013-12-13T00:00:00", "2013-12-16T00:00:00", "2013-12-17T00:00:00", "2013-12-18T00:00:00", "2013-12-19T00:00:00", "2013-12-20T00:00:00", "2013-12-23T00:00:00", "2013-12-24T00:00:00", "2013-12-26T00:00:00", "2013-12-27T00:00:00", "2013-12-30T00:00:00", "2013-12-31T00:00:00", "2014-01-02T00:00:00", "2014-01-03T00:00:00", "2014-01-06T00:00:00", "2014-01-07T00:00:00", "2014-01-08T00:00:00", "2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00 ...

# %% [markdown]
# ## Filter Signals
# That was a lot of repeated signals! If we're already shorting a stock, having an additional signal to short a stock isn't helpful for this strategy. This also applies to additional long signals when the last signal was long.
#
# Implement `filter_signals` to filter out repeated long or short signals within the `lookahead_days`. If the previous signal was the same, change the signal to `0` (do nothing signal). For example, say you have a single stock time series that is
#
# `[1, 0, 1, 0, 1, 0, -1, -1]`
#
# Running `filter_signals` with a lookahead of 3 days should turn those signals into
#
# `[1, 0, 0, 0, 1, 0, -1, 0]`
#
# To help you implement the function, we have provided you with the `clear_signals` function. This will remove all signals within a window after the last signal. For example, say you're using a windows size of 3 with `clear_signals`. It would turn the Series of long signals
#
# `[0, 1, 0, 0, 1, 1, 0, 1, 0]`
#
# into
#
# `[0, 1, 0, 0, 0, 1, 0, 0, 0]`
#
# `clear_signals` only takes a Series of the same type of signals, where `1` is the signal and `0` is no signal. It can't take a mix of long and short signals. Using this function, implement `filter_signals`.
#
# For implementing `filter_signals`, we don't reccommend you try to find a vectorized solution. Instead, you should use the [`iterrows`](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.iterrows.html) over each column.

# %%
def clear_signals(signals, window_size):
    """
    Clear out signals in a Series of just long or short signals.
    
    Remove the number of signals down to 1 within the window size time period.
    
    Parameters
    ----------
    signals : Pandas Series
        The long, short, or do nothing signals
    window_size : int
        The number of days to have a single signal       
    
    Returns
    -------
    signals : Pandas Series
        Signals with the signals removed from the window size
    """
    # Start with buffer of window size
    # This handles the edge case of calculating past_signal in the beginning
    clean_signals = [0]*window_size
    
    for signal_i, current_signal in enumerate(signals):
        # Check if there was a signal in the past window_size of days
        has_past_signal = bool(sum(clean_signals[signal_i:signal_i+window_size]))
        # Use the current signal if there's no past signal, else 0/False
        clean_signals.append(not has_past_signal and current_signal)
        
    # Remove buffer
    clean_signals = clean_signals[window_size:]

    # Return the signals as a Series of Ints
    return pd.Series(np.array(clean_signals).astype(np.int), signals.index)


def filter_signals(signal, lookahead_days):
    """
    Filter out signals in a DataFrame.
    
    Parameters
    ----------
    signal : DataFrame
        The long, short, and do nothing signals for each ticker and date
    lookahead_days : int
        The number of days to look ahead
    
    Returns
    -------
    filtered_signal : DataFrame
        The filtered long, short, and do nothing signals for each ticker and date
    """
    #TODO: Implement function
    filtered_signal = pd.DataFrame()
    shorts = signal.copy()
    shorts[shorts == -1] = 0
    longs = signal.copy()
    longs[longs == 1] = 0
    filtered_signal = shorts.apply(clear_signals, axis=0, window_size=lookahead_days) + longs.apply(clear_signals, axis=0, window_size=lookahead_days)
    return filtered_signal

project_tests.test_filter_signals(filter_signals)
# Out:
# Tests Passed

# %% [markdown]
# ### View Data
# Let's view the same chart as before, but with the redundant signals removed.

# %%
signal_5 = filter_signals(signal, 5)
signal_10 = filter_signals(signal, 10)
signal_20 = filter_signals(signal, 20)
for signal_data, signal_days in [(signal_5, 5), (signal_10, 10), (signal_20, 20)]:
    project_helper.plot_signal(
        close[apple_ticker],
        signal_data[apple_ticker],
        'Long and Short of {} Stock with {} day signal window'.format(apple_ticker, signal_days))
# Out:
# <div>
#
#
#             <div id="61409af8-1448-4d45-906c-1dd6d91d0f93" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("61409af8-1448-4d45-906c-1dd6d91d0f93")) {
#                     Plotly.newPlot(
#                         '61409af8-1448-4d45-906c-1dd6d91d0f93',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013-10-02T00:00:00", "2013-10-03T00:00:00", "2013-10-04T00:00:00", "2013-10-07T00:00:00", "2013-10-08T00:00:00", "2013-10-09T00:00:00", "2013-10-10T00:00:00", "2013-10-11T00:00:00", "2013-10-14T00:00:00", "2013-10-15T00:00:00", "2013-10-16T00:00:00", "2013-10-17T00:00:00", "2013-10-18T00:00:00", "2013-10-21T00:00:00", "2013-10-22T00:00:00", "2013-10-23T00:00:00", "2013-10-24T00:00:00", "2013-10-25T00:00:00", "2013-10-28T00:00:00", "2013-10-29T00:00:00", "2013-10-30T00:00:00", "2013-10-31T00:00:00", "2013-11-01T00:00:00", "2013-11-04T00:00:00", "2013-11-05T00:00:00", "2013-11-06T00:00:00", "2013-11-07T00:00:00", "2013-11-08T00:00:00", "2013-11-11T00:00:00", "2013-11-12T00:00:00", "2013-11-13T00:00:00", "2013-11-14T00:00:00", "2013-11-15T00:00:00", "2013-11-18T00:00:00", "2013-11-19T00:00:00", "2013-11-20T00:00:00", "2013-11-21T00:00:00", "2013-11-22T00:00:00", "2013-11-25T00:00:00", "2013-11-26T00:00:00", "2013-11-27T00:00:00", "2013-11-29T00:00:00", "2013-12-02T00:00:00", "2013-12-03T00:00:00", "2013-12-04T00:00:00", "2013-12-05T00:00:00", "2013-12-06T00:00:00", "2013-12-09T00:00:00", "2013-12-10T00:00:00", "2013-12-11T00:00:00", "2013-12-12T00:00:00", "2013-12-13T00:00:00", "2013-12-16T00:00:00", "2013-12-17T00:00:00", "2013-12-18T00:00:00", "2013-12-19T00:00:00", "2013-12-20T00:00:00", "2013-12-23T00:00:00", "2013-12-24T00:00:00", "2013-12-26T00:00:00", "2013-12-27T00:00:00", "2013-12-30T00:00:00", "2013-12-31T00:00:00", "2014-01-02T00:00:00", "2014-01-03T00:00:00", "2014-01-06T00:00:00", "2014-01-07T00:00:00", "2014-01-08T00:00:00", "2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00 ...
# <div>
#
#
#             <div id="ef7db151-72a7-4e88-9122-00393bfddf73" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ef7db151-72a7-4e88-9122-00393bfddf73")) {
#                     Plotly.newPlot(
#                         'ef7db151-72a7-4e88-9122-00393bfddf73',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013-10-02T00:00:00", "2013-10-03T00:00:00", "2013-10-04T00:00:00", "2013-10-07T00:00:00", "2013-10-08T00:00:00", "2013-10-09T00:00:00", "2013-10-10T00:00:00", "2013-10-11T00:00:00", "2013-10-14T00:00:00", "2013-10-15T00:00:00", "2013-10-16T00:00:00", "2013-10-17T00:00:00", "2013-10-18T00:00:00", "2013-10-21T00:00:00", "2013-10-22T00:00:00", "2013-10-23T00:00:00", "2013-10-24T00:00:00", "2013-10-25T00:00:00", "2013-10-28T00:00:00", "2013-10-29T00:00:00", "2013-10-30T00:00:00", "2013-10-31T00:00:00", "2013-11-01T00:00:00", "2013-11-04T00:00:00", "2013-11-05T00:00:00", "2013-11-06T00:00:00", "2013-11-07T00:00:00", "2013-11-08T00:00:00", "2013-11-11T00:00:00", "2013-11-12T00:00:00", "2013-11-13T00:00:00", "2013-11-14T00:00:00", "2013-11-15T00:00:00", "2013-11-18T00:00:00", "2013-11-19T00:00:00", "2013-11-20T00:00:00", "2013-11-21T00:00:00", "2013-11-22T00:00:00", "2013-11-25T00:00:00", "2013-11-26T00:00:00", "2013-11-27T00:00:00", "2013-11-29T00:00:00", "2013-12-02T00:00:00", "2013-12-03T00:00:00", "2013-12-04T00:00:00", "2013-12-05T00:00:00", "2013-12-06T00:00:00", "2013-12-09T00:00:00", "2013-12-10T00:00:00", "2013-12-11T00:00:00", "2013-12-12T00:00:00", "2013-12-13T00:00:00", "2013-12-16T00:00:00", "2013-12-17T00:00:00", "2013-12-18T00:00:00", "2013-12-19T00:00:00", "2013-12-20T00:00:00", "2013-12-23T00:00:00", "2013-12-24T00:00:00", "2013-12-26T00:00:00", "2013-12-27T00:00:00", "2013-12-30T00:00:00", "2013-12-31T00:00:00", "2014-01-02T00:00:00", "2014-01-03T00:00:00", "2014-01-06T00:00:00", "2014-01-07T00:00:00", "2014-01-08T00:00:00", "2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00 ...
# <div>
#
#
#             <div id="65ac17a2-1f4f-4096-8207-8261ecc2e5cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("65ac17a2-1f4f-4096-8207-8261ecc2e5cb")) {
#                     Plotly.newPlot(
#                         '65ac17a2-1f4f-4096-8207-8261ecc2e5cb',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013-10-02T00:00:00", "2013-10-03T00:00:00", "2013-10-04T00:00:00", "2013-10-07T00:00:00", "2013-10-08T00:00:00", "2013-10-09T00:00:00", "2013-10-10T00:00:00", "2013-10-11T00:00:00", "2013-10-14T00:00:00", "2013-10-15T00:00:00", "2013-10-16T00:00:00", "2013-10-17T00:00:00", "2013-10-18T00:00:00", "2013-10-21T00:00:00", "2013-10-22T00:00:00", "2013-10-23T00:00:00", "2013-10-24T00:00:00", "2013-10-25T00:00:00", "2013-10-28T00:00:00", "2013-10-29T00:00:00", "2013-10-30T00:00:00", "2013-10-31T00:00:00", "2013-11-01T00:00:00", "2013-11-04T00:00:00", "2013-11-05T00:00:00", "2013-11-06T00:00:00", "2013-11-07T00:00:00", "2013-11-08T00:00:00", "2013-11-11T00:00:00", "2013-11-12T00:00:00", "2013-11-13T00:00:00", "2013-11-14T00:00:00", "2013-11-15T00:00:00", "2013-11-18T00:00:00", "2013-11-19T00:00:00", "2013-11-20T00:00:00", "2013-11-21T00:00:00", "2013-11-22T00:00:00", "2013-11-25T00:00:00", "2013-11-26T00:00:00", "2013-11-27T00:00:00", "2013-11-29T00:00:00", "2013-12-02T00:00:00", "2013-12-03T00:00:00", "2013-12-04T00:00:00", "2013-12-05T00:00:00", "2013-12-06T00:00:00", "2013-12-09T00:00:00", "2013-12-10T00:00:00", "2013-12-11T00:00:00", "2013-12-12T00:00:00", "2013-12-13T00:00:00", "2013-12-16T00:00:00", "2013-12-17T00:00:00", "2013-12-18T00:00:00", "2013-12-19T00:00:00", "2013-12-20T00:00:00", "2013-12-23T00:00:00", "2013-12-24T00:00:00", "2013-12-26T00:00:00", "2013-12-27T00:00:00", "2013-12-30T00:00:00", "2013-12-31T00:00:00", "2014-01-02T00:00:00", "2014-01-03T00:00:00", "2014-01-06T00:00:00", "2014-01-07T00:00:00", "2014-01-08T00:00:00", "2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00 ...

# %% [markdown]
# ## Lookahead Close Prices
# With the trading signal done, we can start working on evaluating how many days to short or long the stocks. In this problem, implement `get_lookahead_prices` to get the close price days ahead in time. You can get the number of days from the variable `lookahead_days`. We'll use the lookahead prices to calculate future returns in another problem.

# %%
def get_lookahead_prices(close, lookahead_days):
    """
    Get the lookahead prices for `lookahead_days` number of days.
    
    Parameters
    ----------
    close : DataFrame
        Close price for each ticker and date
    lookahead_days : int
        The number of days to look ahead
    
    Returns
    -------
    lookahead_prices : DataFrame
        The lookahead prices for each ticker and date
    """
    #TODO: Implement function
    return close.shift(-lookahead_days)

project_tests.test_get_lookahead_prices(get_lookahead_prices)
# Out:
# Tests Passed

# %% [markdown]
# ### View Data
# Using the `get_lookahead_prices` function, let's generate lookahead closing prices for 5, 10, and 20 days.
#
# Let's also chart a subsection of a few months of the Apple stock instead of years. This will allow you to view the differences between the 5, 10, and 20 day lookaheads. Otherwise, they will mesh together when looking at a chart that is zoomed out.

# %%
lookahead_5 = get_lookahead_prices(close, 5)
lookahead_10 = get_lookahead_prices(close, 10)
lookahead_20 = get_lookahead_prices(close, 20)
project_helper.plot_lookahead_prices(
    close[apple_ticker].iloc[150:250],
    [
        (lookahead_5[apple_ticker].iloc[150:250], 5),
        (lookahead_10[apple_ticker].iloc[150:250], 10),
        (lookahead_20[apple_ticker].iloc[150:250], 20)],
    '5, 10, and 20 day Lookahead Prices for Slice of {} Stock'.format(apple_ticker))
# Out:
# <div>
#
#
#             <div id="b36e7f2c-5701-414e-b396-9c82ed618198" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b36e7f2c-5701-414e-b396-9c82ed618198")) {
#                     Plotly.newPlot(
#                         'b36e7f2c-5701-414e-b396-9c82ed618198',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00:00", "2014-03-05T00:00:00", "2014-03-06T00:00:00", "2014-03-07T00:00:00", "2014-03-10T00:00:00", "2014-03-11T00:00:00", "2014-03-12T00:00:00", "2014-03-13T00:00:00", "2014-03-14T00:00:00", "2014-03-17T00:00:00", "2014-03-18T00:00:00", "2014-03-19T00:00:00", "2014-03-20T00:00:00", "2014-03-21T00:00:00", "2014-03-24T00:00:00", "2014-03-25T00:00:00", "2014-03-26T00:00:00", "2014-03-27T00:00:00", "2014-03-28T00:00:00", "2014-03-31T00:00:00", "2014-04-01T00:00:00", "2014-04-02T00:00:00", "2014-04-03T00:00:00", "2014-04-04T00:00:00", "2014-04-07T00:00:00", "2014-04-08T00:00:00", "2014-04-09T00:00:00", "2014-04-10T00:00:00", "2014-04-11T00:00:00", "2014-04-14T00:00:00", "2014-04-15T00:00:00", "2014-04-16T00:00:00", "2014-04-17T00:00:00", "2014-04-21T00:00:00", "2014-04-22T00:00:00", "2014-04-23T00:00:00", "2014-04-24T00:00:00", "2014-04-25T00:00:00", "2014-04-28T00:00:00", "2014-04-29T00:00:00", "2014-04-30T00:00:00", "2014-05-01T00:00:00", "2014-05-02T00:00:00", "2014-05-05T00:00:00", "2014-05-06T00:00:00", "2014-05-07T00:00:00", "2014-05-08T00:00:00", "2014-05-09T00:00:00", "2014-05-12T00:00:00", "2014-05-13T00:00:00", "2014-05-14T00:00:00", "2014-05-15T00:00:00", "2014-05-16T00:00:00", "2014-05-19T00:00:00", "2014-05-20T00:00:00", "2014-05-21T00:00:00", "2014-05-22T00:00:00", "2014-05-23T00:00:00", "2014-05-27T00:00:00", "2014-05-28T00:00:00", "2014-05-29T00:00:00", "2014-05-30T00:00:00", "2014-06-02T00:00:00", "2014-06-03T00:00:00", "2014-06-04T00:00:00", "2014-06-05T00:00:00", "2014-06-06T00:00:00", "2014-06-09T00:00:00", "2014-06-10T00:00:00", "2014-06-11T00:00:00", "2014-06-12T00:00:00", "2014-06-13T00:00:00", "2014-06-16T00:00:00", "2014-06-17T00:00:00", "2014-06-18T00:00:00", "2014-06-19T00:00:00", "2014-06-20T00:00:00", "2014-06-23T00:00:00", "2014-06-24T00:00:00", "2014-06-25T00:00:00", "2014-06-26T00:00:00"], "y": [66.85754666005259, 67.35688563548096, 67.74715846627629, 68.6949392436332, 69.92560019721661, 70.8469435749262, 70.84165609499674, 71.96656744999079, 71.90840517076668, 72.17277916724002, 71.03332724243992, 70.21112411340782, 69.43122082381146, 69.7352509197558, 69.00954429943647, 68.38694353774177, 69.7511133595442, 69.56208595206577, 69.76301018938551, 70.22302094324913, 70.37107038127421, 70.15824931411316, 70.1172713446598, 70.18072110381338, 70.86412788469698, 70.93286512378005, 70.14503061428947, 69.35719610479893, 69.62817945118411, 70.244170862967, 70.22566468321386, 69.88726596772797, 70.43848575037491, 71.27390757923067, 72.04059216900335, 71.3518979081903, 71.04522407228124, 70.96591187333921, 70.95004943355082, 71.59908759489285, 71.71805589330587, 71.22103277993598, 70.2996894022264, 69.19592796695021, 69.19196235700309, 70.10140890487139, 69.19724983693257, 68.68568615375665, 68.95931324010654, 68.4675643879663, 68.60637395481464, 69.3902428543581, 70.21376785337256, 70.28369477543976, 69.36512732469313, 75.0518119888347, 75.60303177148164, 78.5309737824239, 78.29832466552736, 78.00222578947721, 78.18596571702619, 78.33137141508655, 79.43909846030984, 78.57327362185963, 78.29832466552736, 78.15952831737886, 77.83419039401828, 78.80289319953012, 78.9265149640757, 78.9411368932155, 78.26985741907009, 79.42498982111438, 80.3661103512034, 80.38206154662863, 80.59474415229845, 80.72235371570036, 81.63423038750979, 83.16288661576172, 82.94754547752102, 84.45892124406228, 84.14255586812841, 83.56432503396353, 84.74604276171655, 85.71374861751431, 86.05005298772974 ...

# %% [markdown]
# ## Lookahead Price Returns
# Implement `get_return_lookahead` to generate the log price return between the closing price and the lookahead price.

# %%
def get_return_lookahead(close, lookahead_prices):
    """
    Calculate the log returns from the lookahead days to the signal day.
    
    Parameters
    ----------
    close : DataFrame
        Close price for each ticker and date
    lookahead_prices : DataFrame
        The lookahead prices for each ticker and date
    
    Returns
    -------
    lookahead_returns : DataFrame
        The lookahead log returns for each ticker and date
    """
    #TODO: Implement function
    
    return np.log(lookahead_prices/close)

project_tests.test_get_return_lookahead(get_return_lookahead)
# Out:
# Tests Passed

# %% [markdown]
# ### View Data
# Using the same lookahead prices and same subsection of the Apple stock from the previous problem, we'll view the lookahead returns.
#
# In order to view price returns on the same chart as the stock, a second y-axis will be added. When viewing this chart, the axis for the price of the stock will be on the left side, like previous charts. The axis for price returns will be located on the right side.

# %%
price_return_5 = get_return_lookahead(close, lookahead_5)
price_return_10 = get_return_lookahead(close, lookahead_10)
price_return_20 = get_return_lookahead(close, lookahead_20)
project_helper.plot_price_returns(
    close[apple_ticker].iloc[150:250],
    [
        (price_return_5[apple_ticker].iloc[150:250], 5),
        (price_return_10[apple_ticker].iloc[150:250], 10),
        (price_return_20[apple_ticker].iloc[150:250], 20)],
    '5, 10, and 20 day Lookahead Returns for Slice {} Stock'.format(apple_ticker))
# Out:
# <div>
#
#
#             <div id="c66226d5-b20e-433b-99c2-265a7db8e9b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c66226d5-b20e-433b-99c2-265a7db8e9b0")) {
#                     Plotly.newPlot(
#                         'c66226d5-b20e-433b-99c2-265a7db8e9b0',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00:00", "2014-03-05T00:00:00", "2014-03-06T00:00:00", "2014-03-07T00:00:00", "2014-03-10T00:00:00", "2014-03-11T00:00:00", "2014-03-12T00:00:00", "2014-03-13T00:00:00", "2014-03-14T00:00:00", "2014-03-17T00:00:00", "2014-03-18T00:00:00", "2014-03-19T00:00:00", "2014-03-20T00:00:00", "2014-03-21T00:00:00", "2014-03-24T00:00:00", "2014-03-25T00:00:00", "2014-03-26T00:00:00", "2014-03-27T00:00:00", "2014-03-28T00:00:00", "2014-03-31T00:00:00", "2014-04-01T00:00:00", "2014-04-02T00:00:00", "2014-04-03T00:00:00", "2014-04-04T00:00:00", "2014-04-07T00:00:00", "2014-04-08T00:00:00", "2014-04-09T00:00:00", "2014-04-10T00:00:00", "2014-04-11T00:00:00", "2014-04-14T00:00:00", "2014-04-15T00:00:00", "2014-04-16T00:00:00", "2014-04-17T00:00:00", "2014-04-21T00:00:00", "2014-04-22T00:00:00", "2014-04-23T00:00:00", "2014-04-24T00:00:00", "2014-04-25T00:00:00", "2014-04-28T00:00:00", "2014-04-29T00:00:00", "2014-04-30T00:00:00", "2014-05-01T00:00:00", "2014-05-02T00:00:00", "2014-05-05T00:00:00", "2014-05-06T00:00:00", "2014-05-07T00:00:00", "2014-05-08T00:00:00", "2014-05-09T00:00:00", "2014-05-12T00:00:00", "2014-05-13T00:00:00", "2014-05-14T00:00:00", "2014-05-15T00:00:00", "2014-05-16T00:00:00", "2014-05-19T00:00:00", "2014-05-20T00:00:00", "2014-05-21T00:00:00", "2014-05-22T00:00:00", "2014-05-23T00:00:00", "2014-05-27T00:00:00", "2014-05-28T00:00:00", "2014-05-29T00:00:00", "2014-05-30T00:00:00", "2014-06-02T00:00:00", "2014-06-03T00:00:00", "2014-06-04T00:00:00", "2014-06-05T00:00:00", "2014-06-06T00:00:00", "2014-06-09T00:00:00", "2014-06-10T00:00:00", "2014-06-11T00:00:00", "2014-06-12T00:00:00", "2014-06-13T00:00:00", "2014-06-16T00:00:00", "2014-06-17T00:00:00", "2014-06-18T00:00:00", "2014-06-19T00:00:00", "2014-06-20T00:00:00", "2014-06-23T00:00:00", "2014-06-24T00:00:00", "2014-06-25T00:00:00", "2014-06-26T00:00:00"], "y": [66.85754666005259, 67.35688563548096, 67.74715846627629, 68.6949392436332, 69.92560019721661, 70.8469435749262, 70.84165609499674, 71.96656744999079, 71.90840517076668, 72.17277916724002, 71.03332724243992, 70.21112411340782, 69.43122082381146, 69.7352509197558, 69.00954429943647, 68.38694353774177, 69.7511133595442, 69.56208595206577, 69.76301018938551, 70.22302094324913, 70.37107038127421, 70.15824931411316, 70.1172713446598, 70.18072110381338, 70.86412788469698, 70.93286512378005, 70.14503061428947, 69.35719610479893, 69.62817945118411, 70.244170862967, 70.22566468321386, 69.88726596772797, 70.43848575037491, 71.27390757923067, 72.04059216900335, 71.3518979081903, 71.04522407228124, 70.96591187333921, 70.95004943355082, 71.59908759489285, 71.71805589330587, 71.22103277993598, 70.2996894022264, 69.19592796695021, 69.19196235700309, 70.10140890487139, 69.19724983693257, 68.68568615375665, 68.95931324010654, 68.4675643879663, 68.60637395481464, 69.3902428543581, 70.21376785337256, 70.28369477543976, 69.36512732469313, 75.0518119888347, 75.60303177148164, 78.5309737824239, 78.29832466552736, 78.00222578947721, 78.18596571702619, 78.33137141508655, 79.43909846030984, 78.57327362185963, 78.29832466552736, 78.15952831737886, 77.83419039401828, 78.80289319953012, 78.9265149640757, 78.9411368932155, 78.26985741907009, 79.42498982111438, 80.3661103512034, 80.38206154662863, 80.59474415229845, 80.72235371570036, 81.63423038750979, 83.16288661576172, 82.94754547752102, 84.45892124406228, 84.14255586812841, 83.56432503396353, 84.74604276171655, 85.71374861751431, 86.05005298772974 ...

# %% [markdown]
# ## Compute the Signal Return
# Using the price returns generate the signal returns.

# %%
def get_signal_return(signal, lookahead_returns):
    """
    Compute the signal returns.
    
    Parameters
    ----------
    signal : DataFrame
        The long, short, and do nothing signals for each ticker and date
    lookahead_returns : DataFrame
        The lookahead log returns for each ticker and date
    
    Returns
    -------
    signal_return : DataFrame
        Signal returns for each ticker and date
    """
    #TODO: Implement function
    
    return signal * lookahead_returns

project_tests.test_get_signal_return(get_signal_return)
# Out:
# Tests Passed

# %% [markdown]
# ### View Data
# Let's continue using the previous lookahead prices to view the signal returns. Just like before, the axis for the signal returns is on the right side of the chart.

# %%
title_string = '{} day LookaheadSignal Returns for {} Stock'
signal_return_5 = get_signal_return(signal_5, price_return_5)
signal_return_10 = get_signal_return(signal_10, price_return_10)
signal_return_20 = get_signal_return(signal_20, price_return_20)
project_helper.plot_signal_returns(
    close[apple_ticker],
    [
        (signal_return_5[apple_ticker], signal_5[apple_ticker], 5),
        (signal_return_10[apple_ticker], signal_10[apple_ticker], 10),
        (signal_return_20[apple_ticker], signal_20[apple_ticker], 20)],
    [title_string.format(5, apple_ticker), title_string.format(10, apple_ticker), title_string.format(20, apple_ticker)])
# Out:
# <div>
#
#
#             <div id="b93be0ef-2cb7-4c6e-b648-2aea03389bd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b93be0ef-2cb7-4c6e-b648-2aea03389bd8")) {
#                     Plotly.newPlot(
#                         'b93be0ef-2cb7-4c6e-b648-2aea03389bd8',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013-10-02T00:00:00", "2013-10-03T00:00:00", "2013-10-04T00:00:00", "2013-10-07T00:00:00", "2013-10-08T00:00:00", "2013-10-09T00:00:00", "2013-10-10T00:00:00", "2013-10-11T00:00:00", "2013-10-14T00:00:00", "2013-10-15T00:00:00", "2013-10-16T00:00:00", "2013-10-17T00:00:00", "2013-10-18T00:00:00", "2013-10-21T00:00:00", "2013-10-22T00:00:00", "2013-10-23T00:00:00", "2013-10-24T00:00:00", "2013-10-25T00:00:00", "2013-10-28T00:00:00", "2013-10-29T00:00:00", "2013-10-30T00:00:00", "2013-10-31T00:00:00", "2013-11-01T00:00:00", "2013-11-04T00:00:00", "2013-11-05T00:00:00", "2013-11-06T00:00:00", "2013-11-07T00:00:00", "2013-11-08T00:00:00", "2013-11-11T00:00:00", "2013-11-12T00:00:00", "2013-11-13T00:00:00", "2013-11-14T00:00:00", "2013-11-15T00:00:00", "2013-11-18T00:00:00", "2013-11-19T00:00:00", "2013-11-20T00:00:00", "2013-11-21T00:00:00", "2013-11-22T00:00:00", "2013-11-25T00:00:00", "2013-11-26T00:00:00", "2013-11-27T00:00:00", "2013-11-29T00:00:00", "2013-12-02T00:00:00", "2013-12-03T00:00:00", "2013-12-04T00:00:00", "2013-12-05T00:00:00", "2013-12-06T00:00:00", "2013-12-09T00:00:00", "2013-12-10T00:00:00", "2013-12-11T00:00:00", "2013-12-12T00:00:00", "2013-12-13T00:00:00", "2013-12-16T00:00:00", "2013-12-17T00:00:00", "2013-12-18T00:00:00", "2013-12-19T00:00:00", "2013-12-20T00:00:00", "2013-12-23T00:00:00", "2013-12-24T00:00:00", "2013-12-26T00:00:00", "2013-12-27T00:00:00", "2013-12-30T00:00:00", "2013-12-31T00:00:00", "2014-01-02T00:00:00", "2014-01-03T00:00:00", "2014-01-06T00:00:00", "2014-01-07T00:00:00", "2014-01-08T00:00:00", "2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00 ...
# <div>
#
#
#             <div id="234b8559-ea00-4a03-9025-72824b4f705b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("234b8559-ea00-4a03-9025-72824b4f705b")) {
#                     Plotly.newPlot(
#                         '234b8559-ea00-4a03-9025-72824b4f705b',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013-10-02T00:00:00", "2013-10-03T00:00:00", "2013-10-04T00:00:00", "2013-10-07T00:00:00", "2013-10-08T00:00:00", "2013-10-09T00:00:00", "2013-10-10T00:00:00", "2013-10-11T00:00:00", "2013-10-14T00:00:00", "2013-10-15T00:00:00", "2013-10-16T00:00:00", "2013-10-17T00:00:00", "2013-10-18T00:00:00", "2013-10-21T00:00:00", "2013-10-22T00:00:00", "2013-10-23T00:00:00", "2013-10-24T00:00:00", "2013-10-25T00:00:00", "2013-10-28T00:00:00", "2013-10-29T00:00:00", "2013-10-30T00:00:00", "2013-10-31T00:00:00", "2013-11-01T00:00:00", "2013-11-04T00:00:00", "2013-11-05T00:00:00", "2013-11-06T00:00:00", "2013-11-07T00:00:00", "2013-11-08T00:00:00", "2013-11-11T00:00:00", "2013-11-12T00:00:00", "2013-11-13T00:00:00", "2013-11-14T00:00:00", "2013-11-15T00:00:00", "2013-11-18T00:00:00", "2013-11-19T00:00:00", "2013-11-20T00:00:00", "2013-11-21T00:00:00", "2013-11-22T00:00:00", "2013-11-25T00:00:00", "2013-11-26T00:00:00", "2013-11-27T00:00:00", "2013-11-29T00:00:00", "2013-12-02T00:00:00", "2013-12-03T00:00:00", "2013-12-04T00:00:00", "2013-12-05T00:00:00", "2013-12-06T00:00:00", "2013-12-09T00:00:00", "2013-12-10T00:00:00", "2013-12-11T00:00:00", "2013-12-12T00:00:00", "2013-12-13T00:00:00", "2013-12-16T00:00:00", "2013-12-17T00:00:00", "2013-12-18T00:00:00", "2013-12-19T00:00:00", "2013-12-20T00:00:00", "2013-12-23T00:00:00", "2013-12-24T00:00:00", "2013-12-26T00:00:00", "2013-12-27T00:00:00", "2013-12-30T00:00:00", "2013-12-31T00:00:00", "2014-01-02T00:00:00", "2014-01-03T00:00:00", "2014-01-06T00:00:00", "2014-01-07T00:00:00", "2014-01-08T00:00:00", "2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00 ...
# <div>
#
#
#             <div id="e08d8b26-d10e-4398-9221-348afc337f9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e08d8b26-d10e-4398-9221-348afc337f9a")) {
#                     Plotly.newPlot(
#                         'e08d8b26-d10e-4398-9221-348afc337f9a',
#                         [{"line": {"color": "black"}, "name": "Index", "type": "scatter", "x": ["2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013-10-02T00:00:00", "2013-10-03T00:00:00", "2013-10-04T00:00:00", "2013-10-07T00:00:00", "2013-10-08T00:00:00", "2013-10-09T00:00:00", "2013-10-10T00:00:00", "2013-10-11T00:00:00", "2013-10-14T00:00:00", "2013-10-15T00:00:00", "2013-10-16T00:00:00", "2013-10-17T00:00:00", "2013-10-18T00:00:00", "2013-10-21T00:00:00", "2013-10-22T00:00:00", "2013-10-23T00:00:00", "2013-10-24T00:00:00", "2013-10-25T00:00:00", "2013-10-28T00:00:00", "2013-10-29T00:00:00", "2013-10-30T00:00:00", "2013-10-31T00:00:00", "2013-11-01T00:00:00", "2013-11-04T00:00:00", "2013-11-05T00:00:00", "2013-11-06T00:00:00", "2013-11-07T00:00:00", "2013-11-08T00:00:00", "2013-11-11T00:00:00", "2013-11-12T00:00:00", "2013-11-13T00:00:00", "2013-11-14T00:00:00", "2013-11-15T00:00:00", "2013-11-18T00:00:00", "2013-11-19T00:00:00", "2013-11-20T00:00:00", "2013-11-21T00:00:00", "2013-11-22T00:00:00", "2013-11-25T00:00:00", "2013-11-26T00:00:00", "2013-11-27T00:00:00", "2013-11-29T00:00:00", "2013-12-02T00:00:00", "2013-12-03T00:00:00", "2013-12-04T00:00:00", "2013-12-05T00:00:00", "2013-12-06T00:00:00", "2013-12-09T00:00:00", "2013-12-10T00:00:00", "2013-12-11T00:00:00", "2013-12-12T00:00:00", "2013-12-13T00:00:00", "2013-12-16T00:00:00", "2013-12-17T00:00:00", "2013-12-18T00:00:00", "2013-12-19T00:00:00", "2013-12-20T00:00:00", "2013-12-23T00:00:00", "2013-12-24T00:00:00", "2013-12-26T00:00:00", "2013-12-27T00:00:00", "2013-12-30T00:00:00", "2013-12-31T00:00:00", "2014-01-02T00:00:00", "2014-01-03T00:00:00", "2014-01-06T00:00:00", "2014-01-07T00:00:00", "2014-01-08T00:00:00", "2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00 ...

# %% [markdown]
# ## Test for Significance
# ### Histogram
# Let's plot a histogram of the signal return values.

# %%
project_helper.plot_signal_histograms(
    [signal_return_5, signal_return_10, signal_return_20],
    'Signal Return',
    ('5 Days', '10 Days', '20 Days'))
# Out:
# /opt/conda/lib/python3.7/site-packages/plotly/tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <div>
#
#
#             <div id="851a540f-ef7c-4da3-a543-ceb8287579de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("851a540f-ef7c-4da3-a543-ceb8287579de")) {
#                     Plotly.newPlot(
#                         '851a540f-ef7c-4da3-a543-ceb8287579de',
#                         [{"marker": {"color": "#b6b2cf"}, "type": "histogram", "x": [0.018935117002154663, 0.027917546482921735, 0.02212204395311001, 0.012960100995248181, 0.019813146563424096, 0.01786503514528187, 0.02957764775473055, 0.01673671815599912, 0.02335431121981514, 0.012528777032737035, 0.022033579375070587, 0.023392022028616382, 0.02848577162483424, 0.014705361327998882, 0.031200079534919715, 0.02071102258539184, 0.0165592191054184, 0.019185365531211446, 0.024164984171189757, 0.01590997425210821, 0.022458756697529995, 0.022569421134860778, 0.01862568138222482, 0.023560632235911066, 0.030941120810971872, 0.010596770993418854, 0.03300799533468518, 0.021696161050419882, 0.030289249081636826, 0.010914430510496067, 0.01905072252016785, 0.01312849173123893, 0.027271200715518362, 0.03701742077747143, 0.023770037277603122, 0.020106766764982357, 0.019204572830600303, 0.01917886189453033, 0.022367449896073713, 0.011493928281985175, 0.026420829742667105, 0.02638489005033305, 0.02715737588225463, 0.018736532824836692, 0.02052183875235076, 0.02775752521887726, 0.023895166196419314, 0.019735239568562896, 0.02484186155030925, 0.028624427955669166, 0.017263152204597038, 0.03205447634923957, 0.026905708762842245, 0.017698766368292176, 0.019044308408092608, 0.017140732204153505, 0.023937503409847648, 0.028060116734593795, 0.029758174967893788, 0.0231544621791741, 0.02681287593772868, 0.0213581012955161, 0.024965458136116486, 0.01954259206369961, 0.014758206013759692, 0.02221423907617087, 0.01927558337249238, 0.024034505061217213, 0.029539030508522933, 0.01923071281179234, 0.01937167924374439, 0.02991677434816445, 0.019750821004784078, 0.016290122489064994, 0.03265144152285602, 0.018406313816474677, 0.031927714581519655, 0.0208922005926158, 0.025297060197901945, 0.0218757675960253, 0.014460707823407722, 0.027141704672974023, 0.02961830297467429, 0.013693659732289176, 0.02181503414737746, 0.022139862475715814, 0.02051826491637204, 0.030892041271011698, 0.01614778189661958, 0.025018656946445297, 0.021966928503843235, 0.02424514596932597, 0.02855610021963788, 0.014122337791989624, 0.028645662778226996, 0.021822407022853547, 0.027388138795487973, 0.025056593335344712, 0.016966186770404117, 0.0234788884164832, 0.027517213064759384, 0.025911770877339237, 0.031104011510671783, 0.028690413440479647, 0.03401447985524705, 0.0218511292061535, 0.02576118558972745, 0.02949300916143101, 0.021050318524978504, 0.027227219068079577, 0.02881904831058293, 0.02423958236916974, 0.017381824163371144, 0.018013072041542674, 0.01964653312818548, 0.011423678056107351, 0.025955871466501315, 0.029369981629920265, 0.03202595106756094, 0.022172528509110657, 0.019512249388519125, 0.026822602629132802, 0.0239196287452915, 0.02499592602867438, 0.026250757295808377, 0.019055920383303906, 0.02163038051024573, 0.019966596947335102, 0.028359091724859623, 0.022689147288068392, 0.014877618040702981, 0.030772331523579926, 0.025156128872789382, 0.02540294058574224, 0.02214358929089877, 0.020387285988692945, 0.030093200511598462, 0.02611371293518554, 0.024046276650068466, 0.03567938564879418, 0.020379351497115453, 0.03179153979074951, 0.020545240593872367, 0.02738115758582879, 0.026651771068229677, 0.02135942538014982, 0.018106554355983153, 0.025868149987461585, 0.02756929310939523, 0.026758229826380455, 0.025097420280815956, 0.028600002098565773, 0.019074510208701732, 0.020890154799569842, 0.026053938464870884, 0.020091631774958277, 0.020374669798372803, 0.028236027341432084, 0.03178549640126895, 0.02812836591799639, 0.016083129488346583, 0.02230770250783363, 0.0193913968276252, 0.03325958964919476, 0.01776682384680102, 0.02506986395426955, 0.028251849503793797, 0.03448816492101238, 0.017707618581669894, 0.028199366123892355, 0.020850237906823627, 0.028423880729609705, 0.025386762614006707, 0.021719726031919927, 0.025749453376022514, 0.02765990857772615, 0.015248470458581128, 0.030532245733352007, 0.020963054337052155, 0.022612603209611656, 0.032379835595927525, 0.01651538 ...

# %% [markdown]
# ### Question: What do the histograms tell you about the signal returns?

# %% [markdown]
# *#TODO: Put Answer In this Cell*
#
# The histograms show that the signal returns have a bell shape quite simimar to a normal distribution with mean = 0. However, in case of 20 days signal return, there might be a fat tail. Also, when the day gap increases, the curve is flatter, as expected, because long term re

# %% [markdown]
# ## Outliers
# You might have noticed the outliers in the 10 and 20 day histograms. To better visualize the outliers, let's compare the 5, 10, and 20 day signals returns to normal distributions with the same mean and deviation for each signal return distributions.

# %%
project_helper.plot_signal_to_normal_histograms(
    [signal_return_5, signal_return_10, signal_return_20],
    'Signal Return',
    ('5 Days', '10 Days', '20 Days'))
# Out:
# <div>
#
#
#             <div id="8da6e4e5-5d8b-472c-8faa-ad059b17fc7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8da6e4e5-5d8b-472c-8faa-ad059b17fc7b")) {
#                     Plotly.newPlot(
#                         '8da6e4e5-5d8b-472c-8faa-ad059b17fc7b',
#                         [{"marker": {"color": "#B6B2CF"}, "name": "Signal Return Distribution", "showlegend": true, "type": "histogram", "x": [0.018935117002154663, 0.027917546482921735, 0.02212204395311001, 0.012960100995248181, 0.019813146563424096, 0.01786503514528187, 0.02957764775473055, 0.01673671815599912, 0.02335431121981514, 0.012528777032737035, 0.022033579375070587, 0.023392022028616382, 0.02848577162483424, 0.014705361327998882, 0.031200079534919715, 0.02071102258539184, 0.0165592191054184, 0.019185365531211446, 0.024164984171189757, 0.01590997425210821, 0.022458756697529995, 0.022569421134860778, 0.01862568138222482, 0.023560632235911066, 0.030941120810971872, 0.010596770993418854, 0.03300799533468518, 0.021696161050419882, 0.030289249081636826, 0.010914430510496067, 0.01905072252016785, 0.01312849173123893, 0.027271200715518362, 0.03701742077747143, 0.023770037277603122, 0.020106766764982357, 0.019204572830600303, 0.01917886189453033, 0.022367449896073713, 0.011493928281985175, 0.026420829742667105, 0.02638489005033305, 0.02715737588225463, 0.018736532824836692, 0.02052183875235076, 0.02775752521887726, 0.023895166196419314, 0.019735239568562896, 0.02484186155030925, 0.028624427955669166, 0.017263152204597038, 0.03205447634923957, 0.026905708762842245, 0.017698766368292176, 0.019044308408092608, 0.017140732204153505, 0.023937503409847648, 0.028060116734593795, 0.029758174967893788, 0.0231544621791741, 0.02681287593772868, 0.0213581012955161, 0.024965458136116486, 0.01954259206369961, 0.014758206013759692, 0.02221423907617087, 0.01927558337249238, 0.024034505061217213, 0.029539030508522933, 0.01923071281179234, 0.01937167924374439, 0.02991677434816445, 0.019750821004784078, 0.016290122489064994, 0.03265144152285602, 0.018406313816474677, 0.031927714581519655, 0.0208922005926158, 0.025297060197901945, 0.0218757675960253, 0.014460707823407722, 0.027141704672974023, 0.02961830297467429, 0.013693659732289176, 0.02181503414737746, 0.022139862475715814, 0.02051826491637204, 0.030892041271011698, 0.01614778189661958, 0.025018656946445297, 0.021966928503843235, 0.02424514596932597, 0.02855610021963788, 0.014122337791989624, 0.028645662778226996, 0.021822407022853547, 0.027388138795487973, 0.025056593335344712, 0.016966186770404117, 0.0234788884164832, 0.027517213064759384, 0.025911770877339237, 0.031104011510671783, 0.028690413440479647, 0.03401447985524705, 0.0218511292061535, 0.02576118558972745, 0.02949300916143101, 0.021050318524978504, 0.027227219068079577, 0.02881904831058293, 0.02423958236916974, 0.017381824163371144, 0.018013072041542674, 0.01964653312818548, 0.011423678056107351, 0.025955871466501315, 0.029369981629920265, 0.03202595106756094, 0.022172528509110657, 0.019512249388519125, 0.026822602629132802, 0.0239196287452915, 0.02499592602867438, 0.026250757295808377, 0.019055920383303906, 0.02163038051024573, 0.019966596947335102, 0.028359091724859623, 0.022689147288068392, 0.014877618040702981, 0.030772331523579926, 0.025156128872789382, 0.02540294058574224, 0.02214358929089877, 0.020387285988692945, 0.030093200511598462, 0.02611371293518554, 0.024046276650068466, 0.03567938564879418, 0.020379351497115453, 0.03179153979074951, 0.020545240593872367, 0.02738115758582879, 0.026651771068229677, 0.02135942538014982, 0.018106554355983153, 0.025868149987461585, 0.02756929310939523, 0.026758229826380455, 0.025097420280815956, 0.028600002098565773, 0.019074510208701732, 0.020890154799569842, 0.026053938464870884, 0.020091631774958277, 0.020374669798372803, 0.028236027341432084, 0.03178549640126895, 0.02812836591799639, 0.016083129488346583, 0.02230770250783363, 0.0193913968276252, 0.03325958964919476, 0.01776682384680102, 0.02506986395426955, 0.028251849503793797, 0.03448816492101238, 0.017707618581669894, 0.028199366123892355, 0.020850237906823627, 0.028423880729609705, 0.025386762614006707, 0.021719726031919927, 0.025749453376022514, 0.02765990857772615, 0.015248470458581128, 0.030532245733352007, 0.0209630543370521 ...

# %% [markdown]
# ## Kolmogorov-Smirnov Test
# While you can see the outliers in the histogram, we need to find the stocks that are causing these outlying returns. We'll use the Kolmogorov-Smirnov Test or KS-Test. This test will be applied to teach ticker's signal returns where a long or short signal exits.

# %%
# Filter out returns that don't have a long or short signal.
long_short_signal_returns_5 = signal_return_5[signal_5 != 0].stack()
long_short_signal_returns_10 = signal_return_10[signal_10 != 0].stack()
long_short_signal_returns_20 = signal_return_20[signal_20 != 0].stack()

# Get just ticker and signal return
long_short_signal_returns_5 = long_short_signal_returns_5.reset_index().iloc[:, [1,2]]
long_short_signal_returns_5.columns = ['ticker', 'signal_return']
long_short_signal_returns_10 = long_short_signal_returns_10.reset_index().iloc[:, [1,2]]
long_short_signal_returns_10.columns = ['ticker', 'signal_return']
long_short_signal_returns_20 = long_short_signal_returns_20.reset_index().iloc[:, [1,2]]
long_short_signal_returns_20.columns = ['ticker', 'signal_return']

# View some of the data
long_short_signal_returns_5.head(10)
# Out:
#    ticker  signal_return
# 0  ALTAIC     0.01893512
# 1  BIFLOR     0.02791755
# 2  DASYST     0.02212204
# 3  GESNER     0.01296010
# 4  GREIGI     0.01981315
# 5  HUMILI     0.01786504
# 6  KAUFMA     0.02957765
# 7  LINIFO     0.01673672
# 8  ORPHAN     0.02335431
# 9  PRAEST     0.01252878

# %% [markdown]
# This gives you the data to use in the KS-Test.
#
# Now it's time to implement the function `calculate_kstest` to use Kolmogorov-Smirnov test (KS test) between a distribution of stock returns (the input dataframe in this case) and each stock's signal returns. Run KS test on a normal distribution against each stock's signal returns. Use [`scipy.stats.kstest`](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.kstest.html#scipy-stats-kstest) perform the KS test. When calculating the standard deviation of the signal returns, make sure to set the delta degrees of freedom to 0.
#
# For this function, we don't reccommend you try to find a vectorized solution. Instead, you should iterate over the [`groupby`](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.groupby.html) function.

# %%
from scipy.stats import kstest


def calculate_kstest(long_short_signal_returns):
    """
    Calculate the KS-Test against the signal returns with a long or short signal.
    
    Parameters
    ----------
    long_short_signal_returns : DataFrame
        The signal returns which have a signal.
        This DataFrame contains two columns, "ticker" and "signal_return"
    
    Returns
    -------
    ks_values : Pandas Series
        KS static for all the tickers
    p_values : Pandas Series
        P value for all the tickers
    """
    #TODO: Implement function
    ks_values = pd.Series()
    p_values = pd.Series()
    normal_args = (np.mean(long_short_signal_returns),np.std(long_short_signal_returns,ddof=0))
    for index, returns in long_short_signal_returns.groupby('ticker'):
        ks_value, p_value = kstest(returns["signal_return"], 'norm', normal_args)
        ks_values[index] = ks_value
        p_values[index] = p_value
    return ks_values, p_values

project_tests.test_calculate_kstest(calculate_kstest)
# Out:
# Tests Passed
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:22: DeprecationWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %% [markdown]
# ### View Data
# Using the signal returns we created above, let's calculate the ks and p values.

# %%
ks_values_5, p_values_5 = calculate_kstest(long_short_signal_returns_5)
ks_values_10, p_values_10 = calculate_kstest(long_short_signal_returns_10)
ks_values_20, p_values_20 = calculate_kstest(long_short_signal_returns_20)

print('ks_values_5')
print(ks_values_5.head(10))
print('p_values_5')
print(p_values_5.head(10))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:22: DeprecationWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# ks_values_5
# AGENEN   0.07739123
# ALTAIC   0.08481774
# ARMENA   0.07427628
# BAKERI   0.05288218
# BIFLOR   0.07917211
# CLUSIA   0.04304667
# DASYST   0.04669648
# GESNER   0.07226246
# GREIGI   0.09179563
# HUMILI   0.06847313
# dtype: float64
# p_values_5
# AGENEN   0.30028232
# ALTAIC   0.20020400
# ARMENA   0.35196437
# BAKERI   0.77892332
# BIFLOR   0.27177873
# CLUSIA   0.93779461
# DASYST   0.88795215
# GESNER   0.37779522
# GREIGI   0.14020815
# HUMILI   0.44690084
# dtype: float64

# %% [markdown]
# ## Find Outliers
# With the ks and p values calculate, let's find which symbols are the outliers. Implement the `find_outliers` function to find the following outliers:
# - Symbols that pass the null hypothesis with a p-value less than `pvalue_threshold`.
# - Symbols that with a KS value above `ks_threshold`.

# %%
def find_outliers(ks_values, p_values, ks_threshold, pvalue_threshold=0.05):
    """
    Find outlying symbols using KS values and P-values
    
    Parameters
    ----------
    ks_values : Pandas Series
        KS static for all the tickers
    p_values : Pandas Series
        P value for all the tickers
    ks_threshold : float
        The threshold for the KS statistic
    pvalue_threshold : float
        The threshold for the p-value
    
    Returns
    -------
    outliers : set of str
        Symbols that are outliers
    """
    #TODO: Implement function
    outliers = set()
    for index in ks_values.index:
        if ks_values[index] > ks_threshold and p_values[index] < pvalue_threshold:
            outliers.add(index)
    return outliers


project_tests.test_find_outliers(find_outliers)
# Out:
# Tests Passed

# %% [markdown]
# ### View Data
# Using the `find_outliers` function you implemented, let's see what we found.

# %%
ks_threshold = 0.8
outliers_5 = find_outliers(ks_values_5, p_values_5, ks_threshold)
outliers_10 = find_outliers(ks_values_10, p_values_10, ks_threshold)
outliers_20 = find_outliers(ks_values_20, p_values_20, ks_threshold)

outlier_tickers = outliers_5.union(outliers_10).union(outliers_20)
print('{} Outliers Found:\n{}'.format(len(outlier_tickers), ', '.join(list(outlier_tickers))))
# Out:
# 0 Outliers Found:

# %% [markdown]
# ### Show Significance without Outliers
# Let's compare the 5, 10, and 20 day signals returns without outliers to normal distributions. Also, let's see how the P-Value has changed with the outliers removed.

# %%
good_tickers = list(set(close.columns) - outlier_tickers)

project_helper.plot_signal_to_normal_histograms(
    [signal_return_5[good_tickers], signal_return_10[good_tickers], signal_return_20[good_tickers]],
    'Signal Return Without Outliers',
    ('5 Days', '10 Days', '20 Days'))
# Out:
# /opt/conda/lib/python3.7/site-packages/plotly/tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <div>
#
#
#             <div id="c621f7d3-73ed-421f-a583-fa99574187cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c621f7d3-73ed-421f-a583-fa99574187cb")) {
#                     Plotly.newPlot(
#                         'c621f7d3-73ed-421f-a583-fa99574187cb',
#                         [{"marker": {"color": "#B6B2CF"}, "name": "Signal Return Distribution", "showlegend": true, "type": "histogram", "x": [0.02212204395311001, 0.023392022028616382, 0.014705361327998882, 0.02848577162483424, 0.01673671815599912, 0.012528777032737035, 0.01786503514528187, 0.022033579375070587, 0.018935117002154663, 0.019813146563424096, 0.02957764775473055, 0.012960100995248181, 0.031200079534919715, 0.027917546482921735, 0.02335431121981514, 0.024164984171189757, 0.01590997425210821, 0.02071102258539184, 0.022458756697529995, 0.0165592191054184, 0.019185365531211446, 0.022569421134860778, 0.01862568138222482, 0.023560632235911066, 0.010596770993418854, 0.030289249081636826, 0.010914430510496067, 0.021696161050419882, 0.01905072252016785, 0.030941120810971872, 0.03300799533468518, 0.022367449896073713, 0.011493928281985175, 0.01312849173123893, 0.023770037277603122, 0.020106766764982357, 0.03701742077747143, 0.027271200715518362, 0.019204572830600303, 0.01917886189453033, 0.026420829742667105, 0.02638489005033305, 0.018736532824836692, 0.02715737588225463, 0.02052183875235076, 0.02775752521887726, 0.019735239568562896, 0.023895166196419314, 0.028624427955669166, 0.026905708762842245, 0.03205447634923957, 0.017698766368292176, 0.02484186155030925, 0.017263152204597038, 0.029758174967893788, 0.023937503409847648, 0.028060116734593795, 0.017140732204153505, 0.019044308408092608, 0.01954259206369961, 0.014758206013759692, 0.0231544621791741, 0.0213581012955161, 0.02221423907617087, 0.02681287593772868, 0.024965458136116486, 0.029539030508522933, 0.01927558337249238, 0.01923071281179234, 0.024034505061217213, 0.01937167924374439, 0.02991677434816445, 0.03265144152285602, 0.019750821004784078, 0.016290122489064994, 0.0208922005926158, 0.02961830297467429, 0.027141704672974023, 0.0218757675960253, 0.025297060197901945, 0.014460707823407722, 0.031927714581519655, 0.018406313816474677, 0.02051826491637204, 0.013693659732289176, 0.02181503414737746, 0.030892041271011698, 0.022139862475715814, 0.021966928503843235, 0.01614778189661958, 0.02424514596932597, 0.025018656946445297, 0.02855610021963788, 0.014122337791989624, 0.021822407022853547, 0.028645662778226996, 0.027388138795487973, 0.025056593335344712, 0.0234788884164832, 0.028690413440479647, 0.031104011510671783, 0.027517213064759384, 0.025911770877339237, 0.016966186770404117, 0.02949300916143101, 0.02576118558972745, 0.03401447985524705, 0.021050318524978504, 0.0218511292061535, 0.017381824163371144, 0.027227219068079577, 0.02423958236916974, 0.02881904831058293, 0.018013072041542674, 0.011423678056107351, 0.01964653312818548, 0.025955871466501315, 0.03202595106756094, 0.029369981629920265, 0.019512249388519125, 0.022172528509110657, 0.0239196287452915, 0.02163038051024573, 0.019055920383303906, 0.026250757295808377, 0.02499592602867438, 0.026822602629132802, 0.022689147288068392, 0.019966596947335102, 0.014877618040702981, 0.028359091724859623, 0.020387285988692945, 0.030772331523579926, 0.030093200511598462, 0.02214358929089877, 0.02540294058574224, 0.025156128872789382, 0.02611371293518554, 0.03567938564879418, 0.024046276650068466, 0.020379351497115453, 0.03179153979074951, 0.02738115758582879, 0.020545240593872367, 0.018106554355983153, 0.02756929310939523, 0.026651771068229677, 0.025868149987461585, 0.02135942538014982, 0.028600002098565773, 0.026758229826380455, 0.025097420280815956, 0.019074510208701732, 0.020374669798372803, 0.020091631774958277, 0.020890154799569842, 0.028236027341432084, 0.026053938464870884, 0.02230770250783363, 0.02812836591799639, 0.03178549640126895, 0.016083129488346583, 0.0193913968276252, 0.03325958964919476, 0.02506986395426955, 0.01776682384680102, 0.017707618581669894, 0.020850237906823627, 0.028251849503793797, 0.028199366123892355, 0.03448816492101238, 0.025386762614006707, 0.025749453376022514, 0.028423880729609705, 0.021719726031919927, 0.020963054337052155, 0.030532245733352007, 0.02765990857772615, 0.0226126032096116 ...

# %% [markdown]
# That's more like it! The returns are closer to a normal distribution. You have finished the research phase of a Breakout Strategy. You can now submit your project.
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
